# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns

# %%
# comparison on human-ROSMAP data
hROSMAP_s = np.load("100_human_ROSMAP_scaden.npy")
hROSMAP_ae = np.load("100_human_ROSMAP_AE.npy")

# %%
sns.set()
sns.scatterplot(hROSMAP_s[:,0],hROSMAP_s[:,1])
sns.scatterplot(hROSMAP_ae[:,0],hROSMAP_ae[:,1])
plt.xlabel("L1 error rate")
plt.ylabel("CCC")
plt.ylim(0.6,1)
plt.xlim(0.1,0.)
plt.legend(["Scaden","AE"],loc='upper left')
plt.title("Deconvolution result of ROSMAP dataset")
# Out:
# /Users/chan/opt/anaconda3/envs/pytorch/lib/python3.7/site-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning
# /Users/chan/opt/anaconda3/envs/pytorch/lib/python3.7/site-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning
# Text(0.5, 1.0, 'Deconvolution result of ROSMAP dataset')

# %%
pbmc_monaco_s = np.load("50_PBMC_Monaco_scaden.npy")
pbmc_monaco_ae = np.load("50_PBMC_Monaco_AE.npy")

# %%
sns.set()
sns.scatterplot(pbmc_monaco_s[:,0],pbmc_monaco_s[:,1])
sns.scatterplot(pbmc_monaco_ae[:,0],pbmc_monaco_ae[:,1])
plt.xlabel("L1 error rate")
plt.ylabel("CCC")
plt.ylim(0.4,0.75)
plt.xlim(0.09,0.04)
plt.legend(["Scaden","AE"],loc='upper left')
plt.title("Deconvolution result of PBMC Monaco's dataset")
# Out:
# /Users/chan/opt/anaconda3/envs/pytorch/lib/python3.7/site-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning
# /Users/chan/opt/anaconda3/envs/pytorch/lib/python3.7/site-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning
# Text(0.5, 1.0, "Deconvolution result of PBMC Monaco's dataset")

# %%
pbmc_sdy67_s = np.load("50_PBMC_sdy67_scaden.npy")
pbmc_sdy67_ae = np.load("50_PBMC_sdy67_AE.npy")

# %%
sns.set()
sns.scatterplot(pbmc_sdy67_s[:,0],pbmc_sdy67_s[:,1])
sns.scatterplot(pbmc_sdy67_ae[:,0],pbmc_sdy67_ae[:,1])
plt.xlabel("L1 error rate")
plt.ylabel("CCC")
plt.ylim(0.2,0.8)
plt.xlim(0.2,0.05)
plt.legend(["Scaden","AE"],loc='upper left')
plt.title("Deconvolution result of PBMC sdy67's dataset")
# Out:
# /Users/chan/opt/anaconda3/envs/pytorch/lib/python3.7/site-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning
# /Users/chan/opt/anaconda3/envs/pytorch/lib/python3.7/site-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning
# Text(0.5, 1.0, "Deconvolution result of PBMC sdy67's dataset")

# %%
pbmc_microarray_s = np.load("50_PBMC_microarray_scaden.npy")
pbmc_microarray_ae = np.load("50_PBMC_microarray_AE.npy")

# %%
sns.set()
sns.scatterplot(pbmc_microarray_s[:,0],pbmc_microarray_s[:,1])
sns.scatterplot(pbmc_microarray_ae[:,0],pbmc_microarray_ae[:,1])
plt.xlabel("L1 error rate")
plt.ylabel("CCC")
plt.ylim(0.2,0.8)
plt.xlim(0.2,0.05)
plt.legend(["Scaden","AE"],loc='upper left')
plt.title("Deconvolution result of PBMC microarray dataset")
# Out:
# /Users/chan/opt/anaconda3/envs/pytorch/lib/python3.7/site-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning
# /Users/chan/opt/anaconda3/envs/pytorch/lib/python3.7/site-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning
# Text(0.5, 1.0, 'Deconvolution result of PBMC microarray dataset')

# %%
mROSMAP_s = np.load("50_mouse_ROSMAP_scaden.npy")
mROSMAP_ae = np.load("50_mouse_ROSMAP_AE.npy")

# %%
sns.set()
sns.scatterplot(mROSMAP_s[:,0],mROSMAP_s[:,1])
sns.scatterplot(mROSMAP_ae[:,0],mROSMAP_ae[:,1])
plt.xlabel("L1 error rate")
plt.ylabel("CCC")
plt.ylim(0.4,1)
plt.xlim(0.1,0.03)
plt.legend(["Scaden","AE"],loc='upper left')
plt.title("Deconvolution result of ROSMAP dataset(mouse referenced)")
# Out:
# /Users/chan/opt/anaconda3/envs/pytorch/lib/python3.7/site-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning
# /Users/chan/opt/anaconda3/envs/pytorch/lib/python3.7/site-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning
# Text(0.5, 1.0, 'Deconvolution result of ROSMAP dataset(mouse referenced)')
