# %%
from TAPE import OverallDeconvolution

# %%
Sigm, Pred = OverallDeconvolution('Kidney_ref.txt', 'Kidney_test.txt',sep='\t',
                                  datatype='counts', genelenfile='./GeneLength.txt',
                                  mode='overall', adaptive=True,
                                  save_model_name = None)
# Out:
# Reading single-cell dataset, this may take 1 min
# Reading dataset is done
# Generating random cell fractions for each pseudo-bulk sample
# Generating cell frations is done
# Sampling cells to compose pseudo-bulk data
# 5000it [00:35, 141.33it/s]
# Sampling is done
# Reading training data
# Reading is done
# Reading test data
# Reading test data is done
# Using counts data to train model
# Variance Cutoff
# Find intersected genes
# Intersected gene number is  16275
# Log2 & MinMax scale
# training data shape is  (5000, 16275)
# test data shape is  (10, 16275)
# Start training
# 100%|██████████| 128/128 [00:47<00:00,  2.67it/s]
# Training is done
# prediction loss is:
# reconstruction loss is:
# Notice that you are using parameters: mode=overall and adaptive=True
# Model is saved without defined name
# Start adaptive training for all the samples
# Adaptive stage is done

# %%
Sigm
# Out:
#                                         0610005C13Rik  0610007C21Rik  \
# endothelial cell                             0.131212       0.104527
# epithelial cell of proximal tubule           0.610616       0.000000
# kidney collecting duct epithelial cell       0.559503       0.946667
# macrophage                                   0.579487       1.000000
# natural killer cell                          0.510898       0.938249
#
#                                         0610007L01Rik  0610007N19Rik  \
# endothelial cell                                  1.0       0.038229
# epithelial cell of proximal tubule                1.0       0.167393
# kidney collecting duct epithelial cell            0.0       0.769735
# macrophage                                        0.0       0.664975
# natural killer cell                               0.0       0.633799
#
#                                         0610007P08Rik  0610007P14Rik  \
# ...

# %%
Pred
# Out:
#    endothelial cell  epithelial cell of proximal tubule  \
# 0          0.290425                            0.149513
# 1          0.261723                            0.247548
# 2          0.215493                            0.189776
# 3          0.231056                            0.057078
# 4          0.243590                            0.126816
# 5          0.197440                            0.325732
# 6          0.158882                            0.091256
# 7          0.105114                            0.213131
# 8          0.376914                            0.127974
# 9          0.158990                            0.249926
#
#    kidney collecting duct epithelial cell  macrophage  natural killer cell
# 0                                0.212118    0.189231             0.227276
# 1                                0.093830    0.402381             0.091033
# 2                                0.183191    0.206717             0.238712
# ...
