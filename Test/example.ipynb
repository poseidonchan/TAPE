# %%
from TAPE import OverallDeconvolution

# %%
Sigm, Pred = OverallDeconvolution('Kidney_ref.txt', 'Kidney_test.txt',sep='\t',
                                  datatype='counts', genelenfile='./GeneLength.txt',
                                  mode='overall', adaptive=True,
                                  save_model_name = None)
# Out:
# Reading single-cell dataset, this may take 1 min
# Reading dataset is done
# Generating random cell fractions for each pseudo-bulk sample
# Generating cell frations is done
# Sampling cells to compose pseudo-bulk data
# 5000it [00:31, 159.98it/s]
# Sampling is done
# Reading training data
# Reading is done
# Reading test data
# Reading test data is done
# Transforming to TPM
# Variance Cutoff
# Find intersected genes
# Intersected gene number is  10540
# Log2 & MinMax scale
# training data shape is  (5000, 10540)
# test data shape is  (12, 10540)
# Start training
# 100%|█████████████████████████████████████████| 128/128 [10:00<00:00,  4.69s/it]
# Training is done
# prediction loss is:
# reconstruction loss is:
# Notice that you are using parameters: mode=overall and adaptive=True
# Model is saved without defined name
# Start adaptive training for all the samples
# test tensor([1.0000, 1.0000, 1.0000, 1.0000, 1.0000, 1.0000, 1.0000, 1.0000, 1.0000,
#         1.0000, 1.0000, 1.0000], grad_fn=<SumBackward1>)
# Adaptive stage is done
# (            LINC00115     NOC2L    KLHL17     ISG15      AGRN  C1orf159  \
#  Bcells       0.271055  0.307225  0.102723  0.453505  0.000000  0.000000
#  CD4Tcells    0.000000  0.320321  0.067262  0.000000  0.097109  0.474209
#  CD8Tcells    0.152616  0.295200  0.000000  0.446277  0.029841  0.021963
#  Dendritics   0.477968  0.248134  0.000000  0.513301  0.045252  0.000000
#  Monocytes    0.125982  0.246992  0.000000  0.349775  0.026954  0.022865
#  NK           0.213160  0.310998  0.233564  0.504149  0.000000  0.072608
#  Unknown      0.187724  0.317625  0.000000  0.557430  0.000000  0.000000
#
#              TNFRSF18   TNFRSF4      SDF4    UBE2J2  ...    MT-CO2   MT-ATP8  \
#  Bcells      0.259968  0.224429  0.307790  0.232637  ...  1.000000  0.479131
#  CD4Tcells   0.000000  0.128395  0.289046  0.443292  ...  0.110689  0.895486
#  CD8Tcells   0.295537  0.212179  0.315770  0.260087  ...  1.000000  0.432925
#  Dendritics  0.219849  0.183540  0.292097  0.275077  ...  0.944573  0.478621
#  Monocytes   0.000000  0.000000  0.265149  0.225181  ...  0.921309  0.407045
#  NK          0.669120  0.461105  0.396603  0.289543  ...  1.000000  0.388962
#  Unknown     0.248510  0.217001  0.542381  0.307068  ...  1.000000  0.347242
#
#               MT-ATP6    MT-CO3    MT-ND3   MT-ND4L    MT-ND4    MT-ND5  \
#  Bcells      0.895829  1.000000  0.755911  0.662554  0.892035  0.658018
#  CD4Tcells   0.240186  0.104918  0.000000  0.923419  0.436914  0.629127
#  CD8Tcells   0.871328  0.933132  0.684981  0.630647  0.854094  0.661988
#  Dendritics  0.855412  0.942716  0.742901  0.596504  0.847980  0.652002
#  Monocytes   0.840660  0.891806  0.602384  0.576396  0.813907  0.628070
#  NK          0.892863  0.966688  0.721226  0.635651  0.879095  0.683961
#  Unknown     0.925191  1.000000  0.780074  0.742460  0.942783  0.766889
#
#                MT-ND6    MT-CYB
#  Bcells      0.579593  0.884055
#  CD4Tcells   0.673493  0.540716
#  CD8Tcells   0.595891  0.868787
#  Dendritics  0.476154  0.853351
#  Monocytes   0.494948  0.819365
#  NK          0.597663  0.877249
#  Unknown     0.604729  0.917400
#
#  [7 rows x 10540 columns],
#          Bcells  CD4Tcells  CD8Tcells  Dendritics  Monocytes        NK  Unknown
#  CYFZ  0.194426   0.357007        0.0         0.0   0.217249  0.231319      0.0
#  FY2H  0.167651   0.324567        0.0         0.0   0.333942  0.173840      0.0
#  FLWA  0.177510   0.362930        0.0         0.0   0.231310  0.228250      0.0
#  453W  0.158984   0.380058        0.0         0.0   0.233870  0.227087      0.0
#  684C  0.199639   0.400515        0.0         0.0   0.191005  0.208841      0.0
#  CZJE  0.207493   0.361401        0.0         0.0   0.225243  0.205862      0.0
#  925L  0.259393   0.357071        0.0         0.0   0.198258  0.185278      0.0
#  9JD4  0.200783   0.410622        0.0         0.0   0.177387  0.211208      0.0
#  G4YW  0.173874   0.350748        0.0         0.0   0.250002  0.225376      0.0
#  4DUY  0.188302   0.378950        0.0         0.0   0.212825  0.219923      0.0
#  36TS  0.140579   0.328235        0.0         0.0   0.352560  0.178626      0.0
#  CR3L  0.222959   0.368736        0.0         0.0   0.229836  0.178469      0.0)
