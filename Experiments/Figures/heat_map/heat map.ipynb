# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
from pandas import Series,DataFrame
import seaborn as sns
import palettable#python颜色库
from sklearn import datasets

# %%
ccc_real = pd.read_excel('ccc_real.xlsx',index_col=0)
ccc_pseudo = pd.read_excel('ccc_pseudo.xlsx',index_col=0)
mea_real = pd.read_excel('mea_real.xlsx',index_col=0)
mea_pseudo = pd.read_excel('mea_pseudo.xlsx',index_col=0)
plt.clf()
plt.figure(dpi=120,figsize=(8,6))


plt.subplot(2,2,1)
sns.heatmap(data=ccc_real,#矩阵数据集，数据的index和columns分别为heatmap的y轴方向和x轴方向标签
            vmin=-0.5,#图例（右侧颜色条color bar）中最小显示值 
            vmax=1,#图例（右侧颜色条color bar）中最大显示值
            cmap=plt.get_cmap('tab20b'),#使用matplotlib中的颜色盘
#             cmap=sns.cubehelix_palette(as_cmap=True),#渐变色盘：sns.cubehelix_palette()使用
            annot=True,#默认为False，当为True时，在每个格子写入data中数据
            fmt=".2f",#设置每个格子中数据的格式，参考之前的文章，此处保留两位小数
            mask=ccc_real<-0.5,#热图中显示部分数据：显示数值小于6的数据 
#             xticklabels=['三连啊','关注公众号啊','pythonic生物人','收藏啊','点赞啊','老铁三连三连'] , #x轴方向刻度标签开关、赋值，可选“auto”, bool, list-like（传入列表）, or int,
#             yticklabels=True, #y轴方向刻度标签开关、同x轴
            cbar=False,#右侧图例(color bar)开关，默认为True显示
           )
plt.title('CCC_real')

plt.subplot(2,2,2)
sns.heatmap(data=ccc_pseudo,#矩阵数据集，数据的index和columns分别为heatmap的y轴方向和x轴方向标签
            vmin=-0.5,#图例（右侧颜色条color bar）中最小显示值 
            vmax=1,#图例（右侧颜色条color bar）中最大显示值
            cmap=plt.get_cmap('tab20b'),#使用matplotlib中的颜色盘
#             cmap=sns.cubehelix_palette(as_cmap=True),#渐变色盘：sns.cubehelix_palette()使用
            annot=True,#默认为False，当为True时，在每个格子写入data中数据
            fmt=".2f",#设置每个格子中数据的格式，参考之前的文章，此处保留两位小数
            mask=ccc_real<-0.5,#热图中显示部分数据：显示数值小于6的数据 
#             xticklabels=['三连啊','关注公众号啊','pythonic生物人','收藏啊','点赞啊','老铁三连三连'] , #x轴方向刻度标签开关、赋值，可选“auto”, bool, list-like（传入列表）, or int,
#             yticklabels=True, #y轴方向刻度标签开关、同x轴
           )

plt.title('CCC_pseudo')

plt.subplot(2,2,3)
sns.heatmap(data=mea_real,#矩阵数据集，数据的index和columns分别为heatmap的y轴方向和x轴方向标签
            vmin=-0.5,#图例（右侧颜色条color bar）中最小显示值 
            vmax=1,#图例（右侧颜色条color bar）中最大显示值
            cmap=plt.get_cmap('tab20b'),#使用matplotlib中的颜色盘
#             cmap=sns.cubehelix_palette(as_cmap=True),#渐变色盘：sns.cubehelix_palette()使用
            annot=True,#默认为False，当为True时，在每个格子写入data中数据
            fmt=".2f",#设置每个格子中数据的格式，参考之前的文章，此处保留两位小数
            mask=ccc_real<-0.5,#热图中显示部分数据：显示数值小于6的数据 
#             xticklabels=['三连啊','关注公众号啊','pythonic生物人','收藏啊','点赞啊','老铁三连三连'] , #x轴方向刻度标签开关、赋值，可选“auto”, bool, list-like（传入列表）, or int,
#             yticklabels=True, #y轴方向刻度标签开关、同x轴
            cbar=False,#右侧图例(color bar)开关，默认为True显示
           )
plt.title('MEA_real')

plt.subplot(2,2,4)
sns.heatmap(data=mea_pseudo,#矩阵数据集，数据的index和columns分别为heatmap的y轴方向和x轴方向标签
            vmin=-0.5,#图例（右侧颜色条color bar）中最小显示值 
            vmax=1,#图例（右侧颜色条color bar）中最大显示值
            cmap=plt.get_cmap('tab20b'),#使用matplotlib中的颜色盘
#             cmap=sns.cubehelix_palette(as_cmap=True),#渐变色盘：sns.cubehelix_palette()使用
            annot=True,#默认为False，当为True时，在每个格子写入data中数据
            fmt=".2f",#设置每个格子中数据的格式，参考之前的文章，此处保留两位小数
            mask=ccc_real<-0.5,#热图中显示部分数据：显示数值小于6的数据 
#             xticklabels=['三连啊','关注公众号啊','pythonic生物人','收藏啊','点赞啊','老铁三连三连'] , #x轴方向刻度标签开关、赋值，可选“auto”, bool, list-like（传入列表）, or int,
#             yticklabels=True, #y轴方向刻度标签开关、同x轴
           )

plt.title('MEA_pseudo')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /var/folders/zg/mdwszbl52b7c41q6yywhqkwm0000gn/T/ipykernel_11540/526919361.py in <module>
#      23
#      24 plt.subplot(2,2,2)
# ---> 25 sns.heatmap(data=ccc_pseudo,#矩阵数据集，数据的index和columns分别为heatmap的y轴方向和x轴方向标签
#      26             vmin=-0.5,#图例（右侧颜色条color bar）中最小显示值
#      27             vmax=1,#图例（右侧颜色条color bar）中最大显示值
#
# ~/opt/anaconda3/lib/python3.8/site-packages/seaborn/_decorators.py in inner_f(*args, **kwargs)
#      44             )
#      45         kwargs.update({k: arg for k, arg in zip(sig.parameters, args)})
# ---> 46         return f(**kwargs)
#      47     return inner_f
#      48
#
# ~/opt/anaconda3/lib/python3.8/site-packages/seaborn/matrix.py in heatmap(data, vmin, vmax, cmap, center, robust, annot, fmt, annot_kws, linewidths, linecolor, cbar, cbar_kws, cbar_ax, square, xticklabels, yticklabels, mask, ax, **kwargs)
#     533     """
#     534     # Initialize the plotter object
# --> 535     plotter = _HeatMapper(data, vmin, vmax, cmap, center, robust, annot, fmt,
#     536                           annot_kws, cbar, cbar_kws, xticklabels,
#     537                           yticklabels, mask)
#
# ~/opt/anaconda3/lib/python3.8/site-packages/seaborn/matrix.py in __init__(self, data, vmin, vmax, cmap, center, robust, annot, fmt, annot_kws, cbar, cbar_kws, xticklabels, yticklabels, mask)
#     103
#     104         # Validate the mask and convet to DataFrame
# --> 105         mask = _matrix_mask(data, mask)
#     106
#     107         plot_data = np.ma.masked_where(np.asarray(mask), plot_data)
#
# ~/opt/anaconda3/lib/python3.8/site-packages/seaborn/matrix.py in _matrix_mask(data, mask)
#      77            and mask.columns.equals(data.columns):
#      78             err = "Mask must have the same index and columns as data."
# ---> 79             raise ValueError(err)
#      80
#      81     # Add any cells with missing data to the mask
#
# ValueError: Mask must have the same index and columns as data.
