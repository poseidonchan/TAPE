# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
sns.set_context("paper")

# %%
pbmc = pd.read_csv('COVID_pbmc_data.csv',index_col=0)

# %%
tape = pd.read_csv('COVIDisletpred_tape.csv',index_col=0)
scaden = pd.read_csv('COVIDisletpred_scaden.csv',index_col=0)
csx = pd.read_csv('COVIDisletpred_csx.csv',index_col=0)
music = pd.read_csv('COVIDisletpred_music.csv',index_col=0)
rnasieve = pd.read_csv('COVIDisletpred_rnasieve.csv',index_col=0)
dwls = pd.read_csv('COVIDisletpred_dwls.txt',sep='\t',index_col=0)
bisque = pd.read_csv('COVIDisletpred_bisque.csv',index_col=0).T
tape['sample'] = ['normal_culture','normal_culture',
                  'covid19_infection', 'covid19_infection',
                  'infection+Remdesivir', 'infection+Remdesivir']
scaden['sample'] = ['normal_culture','normal_culture',
                    'covid19_infection', 'covid19_infection',
                    'infection+Remdesivir', 'infection+Remdesivir']
csx['sample'] = ['normal_culture','normal_culture',
                 'covid19_infection', 'covid19_infection',
                 'infection+Remdesivir', 'infection+Remdesivir']
rnasieve['sample'] = ['normal_culture','normal_culture',
                      'covid19_infection', 'covid19_infection',
                      'infection+Remdesivir', 'infection+Remdesivir']
music['sample'] = ['normal_culture','normal_culture',
                   'covid19_infection', 'covid19_infection',
                   'infection+Remdesivir', 'infection+Remdesivir']
dwls['sample'] = ['normal_culture','normal_culture',
                  'covid19_infection', 'covid19_infection',
                  'infection+Remdesivir', 'infection+Remdesivir']
bisque['sample'] = ['normal_culture','normal_culture',
                  'covid19_infection', 'covid19_infection',
                  'infection+Remdesivir', 'infection+Remdesivir']
tape['model'] = ['TAPE' for i in range(len(tape))]
scaden['model'] = ['Scaden' for i in range(len(tape))]
rnasieve['model'] = ['RNAsieve' for i in range(len(tape))]
csx['model'] = ['CIBERSORTx' for i in range(len(tape))]
music['model'] = ['MuSiC' for i in range(len(tape))]
dwls['model'] = ['DWLS' for i in range(len(tape))]
bisque['model'] = ['Bisque' for i in range(len(tape))]
data = pd.concat([tape,scaden,rnasieve,csx,dwls,music,bisque])

# %%
# colors = sns.color_palette('colorblind',5)
# fig,axes = plt.subplots(1,2,figsize=(10,4))

# sns.lineplot(x='sample',y='beta',hue='model',
#              data=data,palette='colorblind',
#              ax=axes[0],
#              ci=60)
# sns.lineplot(data=pbmc,x='Type',y='MLR',hue='model',
#              ax=axes[1],
#              ci=60,palette='colorblind')
# axes[0].spines['top'].set_visible(False)
# axes[0].spines['right'].set_visible(False)
# axes[0].get_legend().set_visible(False)
# axes[1].spines['top'].set_visible(False)
# axes[1].spines['right'].set_visible(False)
# axes[1].get_legend().set_visible(False)
# handles, labels = axes[1].get_legend_handles_labels()
# fig.legend(handles, labels, loc='upper right')
# #fig.subplots_adjust(left=None, bottom=None, right=None, top=None,wspace=None, hspace=None)
# plt.tight_layout()
# plt.show()

# %%
colors = sns.color_palette('Blues',3)

# %%
fig,ax = plt.subplots(figsize=(6,4))
sns.barplot(data=data,x='model',y='beta',hue='sample',ci=95,errwidth=0.5,errcolor='black',capsize=0.1,
            palette={'normal_culture':colors[0],
                     'covid19_infection':colors[2],
                     'infection+Remdesivir':colors[0]})
ax.spines['top'].set_visible(False)
ax.spines['right'].set_visible(False)
plt.tight_layout()
# S_3_Rem_5dpi_S69995   0.629101  0.063810  0.002016  0.267039  0.038034
# S_2_mock_5dpi_S70002  0.000000  0.327302  0.188029  0.105583  0.379086
# S_3_mock_5dpi_S69997  0.543312  0.000000  0.456688  0.000000  0.000000
# S_2_SARS_5dpi_S70003  0.480464  0.397257  0.000000  0.031302  0.090977
# S_3_SARS_5dpi_S69996  0.011828  0.052882  0.734423  0.200866  0.000000
# S_2_Rem_5dpi_S70001   0.177978  0.604257  0.000000  0.000000  0.217765
# S_3_Rem_5dpi_S69995   0.034056  0.036652  0.244196  0.030549  0.654547
#
#                                     sample       model  P-value  Correlation  \
# S_2_mock_5dpi_S70002        normal_culture        TAPE      NaN          NaN
# S_3_mock_5dpi_S69997        normal_culture        TAPE      NaN          NaN
# S_2_SARS_5dpi_S70003     covid19_infection        TAPE      NaN          NaN
# S_3_SARS_5dpi_S69996     covid19_infection        TAPE      NaN          NaN
# S_2_Rem_5dpi_S70001   infection+Remdesivir        TAPE      NaN          NaN
# S_3_Rem_5dpi_S69995   infection+Remdesivir        TAPE      NaN          NaN
# S_2_mock_5dpi_S70002        normal_culture      Scaden      NaN          NaN
# S_3_mock_5dpi_S69997        normal_culture      Scaden      NaN          NaN
# S_2_SARS_5dpi_S70003     covid19_infection      Scaden      NaN          NaN
# S_3_SARS_5dpi_S69996     covid19_infection      Scaden      NaN          NaN
# S_2_Rem_5dpi_S70001   infection+Remdesivir      Scaden      NaN          NaN
# S_3_Rem_5dpi_S69995   infection+Remdesivir      Scaden      NaN          NaN
# Bulk 0                      normal_culture    RNAsieve      NaN          NaN
# Bulk 1                      normal_culture    RNAsieve      NaN          NaN
# Bulk 2                   covid19_infection    RNAsieve      NaN          NaN
# Bulk 3                   covid19_infection    RNAsieve      NaN          NaN
# Bulk 4                infection+Remdesivir    RNAsieve      NaN          NaN
# Bulk 5                infection+Remdesivir    RNAsieve      NaN          NaN
# S_2_mock_5dpi_S70002        normal_culture  CIBERSORTx      0.0     0.591709
# S_3_mock_5dpi_S69997        normal_culture  CIBERSORTx      0.0     0.198757
# S_2_SARS_5dpi_S70003     covid19_infection  CIBERSORTx      0.0     0.514480
# S_3_SARS_5dpi_S69996     covid19_infection  CIBERSORTx      0.0     0.258023
# S_2_Rem_5dpi_S70001   infection+Remdesivir  CIBERSORTx      0.0     0.658044
# S_3_Rem_5dpi_S69995   infection+Remdesivir  CIBERSORTx      0.0     0.226533
# 0                           normal_culture        DWLS      NaN          NaN
# 1                           normal_culture        DWLS      NaN          NaN
# 2                        covid19_infection        DWLS      NaN          NaN
# 3                        covid19_infection        DWLS      NaN          NaN
# 4                     infection+Remdesivir        DWLS      NaN          NaN
# 5                     infection+Remdesivir        DWLS      NaN          NaN
# S_2_mock_5dpi_S70002        normal_culture       MuSiC      NaN          NaN
# S_3_mock_5dpi_S69997        normal_culture       MuSiC      NaN          NaN
# S_2_SARS_5dpi_S70003     covid19_infection       MuSiC      NaN          NaN
# S_3_SARS_5dpi_S69996     covid19_infection       MuSiC      NaN          NaN
# S_2_Rem_5dpi_S70001   infection+Remdesivir       MuSiC      NaN          NaN
# S_3_Rem_5dpi_S69995   infection+Remdesivir       MuSiC      NaN          NaN
# S_2_mock_5dpi_S70002        normal_culture      Bisque      NaN          NaN
# S_3_mock_5dpi_S69997        normal_culture      Bisque      NaN          NaN
# S_2_SARS_5dpi_S70003     covid19_infection      Bisque      NaN          NaN
# S_3_SARS_5dpi_S69996     covid19_infection      Bisque      NaN          NaN
# S_2_Rem_5dpi_S70001   infection+Remdesivir      Bisque      NaN          NaN
# S_3_Rem_5dpi_S69995   infection+Remdesivir      Bisque      NaN          NaN
#
#                           RMSE
# S_2_mock_5dpi_S70002       NaN
# S_3_mock_5dpi_S69997       NaN
# S_2_SARS_5dpi_S70003       NaN
# S_3_SARS_5dpi_S69996       NaN
# S_2_Rem_5dpi_S70001        NaN
# S_3_Rem_5dpi_S69995        NaN
# S_2_mock_5dpi_S70002       NaN
# S_3_mock_5dpi_S69997       NaN
# S_2_SARS_5dpi_S70003       NaN
# S_3_SARS_5dpi_S69996       NaN
# S_2_Rem_5dpi_S70001        NaN
# S_3_Rem_5dpi_S69995        NaN
# Bulk 0                     NaN
# Bulk 1                     NaN
# Bulk 2                     NaN
# Bulk 3                     NaN
# Bulk 4                     NaN
# Bulk 5                     NaN
# S_2_mock_5dpi_S70002  0.837253
# S_3_mock_5dpi_S69997  0.983192
# S_2_SARS_5dpi_S70003  0.867214
# S_3_SARS_5dpi_S69996  0.966846
# S_2_Rem_5dpi_S70001   0.786012
# S_3_Rem_5dpi_S69995   0.975820
# 0                          NaN
# 1                          NaN
# 2                          NaN
# 3                          NaN
# 4                          NaN
# 5                          NaN
# S_2_mock_5dpi_S70002       NaN
# S_3_mock_5dpi_S69997       NaN
# S_2_SARS_5dpi_S70003       NaN
# S_3_SARS_5dpi_S69996       NaN
# S_2_Rem_5dpi_S70001        NaN
# S_3_Rem_5dpi_S69995        NaN
# S_2_mock_5dpi_S70002       NaN
# S_3_mock_5dpi_S69997       NaN
# S_2_SARS_5dpi_S70003       NaN
# S_3_SARS_5dpi_S69996       NaN
# S_2_Rem_5dpi_S70001        NaN
# S_3_Rem_5dpi_S69995        NaN

# %%
from scipy import stats
stats.ttest_ind([0.291421, 0.267504], [0.245460, 0.235373],equal_var=True,alternative='greater')
# Out:
# Ttest_indResult(statistic=3.0085037909288164, pvalue=0.04750070170122387)

# %%
stats.ttest_ind([0.278552, 0.271998], [0.245460, 0.235373],equal_var=True,alternative='greater')
# Out:
# Ttest_indResult(statistic=5.795630589405617, pvalue=0.014252280570741767)

# %%
stats.ttest_ind([0.250076, 0.238943], [0.190246, 0.221677],equal_var=True,alternative='greater')
# Out:
# Ttest_indResult(statistic=2.3121098430939813, pvalue=0.07346234006204576)

# %%
stats.ttest_ind([0.246976, 0.232293], [0.190246, 0.221677],equal_var=True,alternative='greater')
# Out:
# Ttest_indResult(statistic=1.9412839970346123, pvalue=0.0958668416490819)
