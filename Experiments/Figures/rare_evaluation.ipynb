# %%
import numpy as np
import pandas as pd
from TAPE.utils import CCCscore, L1error

# %%
## rare celltype in Limb_Muscle is skeletal muscle satellite cell, endothelial cell

## rare celltype in Lung is T cell, ciliated columnar cell of tracheobronchial tree, natural killer
## rare celltype in Marrow is monocyte, hematopoietic precursor cell

rare_celltype_lm = ['skeletal muscle satellite cell', 'endothelial cell']
rare_celltype_marrow = ['monocyte', 'hematopoietic precursor cell']
rare_celltype_lung = ['T cell', 'ciliated columnar cell of tracheobronchial tree', 'natural killer']

# %%
record = pd.DataFrame(columns=['CellType','Method','DataType','Tissue','CCC','L1error','abundant'])

# %%
### rare
names = ['Limb_Muscle','Lung', 'Marrow']
tasks = ['umi2counts','counts2umi']
for name in names:
    for task in tasks:
        print('#################################################################################')
        print("################## Evaluating DWLS's prediction of "+name+' ('+task+") ##################")
        print('#################################################################################')
        pred = pd.read_csv('./DWLS/rare/'+name+'_'+task+'_pred.csv',index_col=0).T
        label = pd.read_csv('./TabularMuris/rare/'+name+'_pseudobulk_'+task.split('2')[-1]+'_label.txt',sep='\t',index_col=0)
        pred.columns = [x.replace(".", " ") for x in pred.columns]
        inter = pred.columns.intersection(label.columns)
        label = label[inter]
        pred = pred[inter]
        overall_ccc = CCCscore(label.values,pred.values)
        overall_l1 = L1error(label.values,pred.values)
        print('Overall ccc score is',overall_ccc)
        print('Overall L1 error is',overall_l1)
        if name == 'Limb_Muscle':
            rare = rare_celltype_lm
        elif name == 'Lung':
            rare = rare_celltype_lung
        elif name == 'Marrow':
            rare = rare_celltype_marrow
        
        for i in range(pred.shape[1]):
            score = CCCscore(label.iloc[:,i].values,pred.iloc[:,i].values)
            error = L1error(label.iloc[:,i].values,pred.iloc[:,i].values)
            celltype = pred.columns[i]
            if celltype in rare:
                abundant = 'rare'
            else:
                abundant = 'normal'
            print(celltype+"'s ccc score is",score,"l1 error is",error)
            record = record.append({'CellType':celltype,'CCC':score,'L1error':error,
                                    'DataType':task,'Tissue':name,'Method':'DWLS','abundant':abundant},ignore_index=True)
# Out:
# #################################################################################
# ################## Evaluating DWLS's prediction of Limb_Muscle (umi2counts) ##################
# #################################################################################
# Overall ccc score is 0.9639703307681747
# Overall L1 error is 0.03637234823692142
# skeletal muscle satellite cell's ccc score is 0.20986833343894493 l1 error is 0.011399586239933163
# mesenchymal stem cell's ccc score is 0.9736375027521955 l1 error is 0.03967475195916457
# endothelial cell's ccc score is 0.10110758373447945 l1 error is 0.03794986785674846
# B cell's ccc score is 0.978186765683159 l1 error is 0.031466259654188165
# macrophage's ccc score is 0.9718147353970602 l1 error is 0.03498825681261426
# T cell's ccc score is 0.892410574932403 l1 error is 0.0627553668988799
# #################################################################################
# ################## Evaluating DWLS's prediction of Limb_Muscle (counts2umi) ##################
# #################################################################################
# Overall ccc score is 0.7876566537239506
# Overall L1 error is 0.0748830781974938
# skeletal muscle satellite cell's ccc score is 0.0033014296072036223 l1 error is 0.19467506085741962
# mesenchymal stem cell's ccc score is 0.8599201813861705 l1 error is 0.07167195639168245
# endothelial cell's ccc score is 0.26066605115640157 l1 error is 0.013927123767100981
# B cell's ccc score is 0.9078248904894217 l1 error is 0.05618664255196801
# macrophage's ccc score is 0.8920952182223566 l1 error is 0.06554632414434096
# T cell's ccc score is 0.9239889221312471 l1 error is 0.04729136147245077
# #################################################################################
# ################## Evaluating DWLS's prediction of Lung (umi2counts) ##################
# #################################################################################
# Overall ccc score is 0.8914316762814892
# Overall L1 error is 0.04331133467911008
# lung endothelial cell's ccc score is 0.875181064595168 l1 error is 0.0574695693588439
# stromal cell's ccc score is 0.910362979189639 l1 error is 0.04825059768219881
# classical monocyte's ccc score is 0.8970906361418926 l1 error is 0.04971128811572756
# myeloid cell's ccc score is 0.7247078267069289 l1 error is 0.06576163987170941
# B cell's ccc score is 0.9599706338300088 l1 error is 0.02681312947875704
# T cell's ccc score is 0.10941767369701415 l1 error is 0.026050288377692896
# natural killer cell's ccc score is 0.3666667561077125 l1 error is 0.014891106426851083
# leukocyte's ccc score is 0.7954446411804502 l1 error is 0.08704175324192058
# ciliated columnar cell of tracheobronchial tree's ccc score is 0.022205277512837754 l1 error is 0.013812639558289451
# #################################################################################
# ################## Evaluating DWLS's prediction of Lung (counts2umi) ##################
# #################################################################################
# Overall ccc score is 0.6813329842163552
# Overall L1 error is 0.07483796414277
# lung endothelial cell's ccc score is 0.8040296433362799 l1 error is 0.05868450194620131
# stromal cell's ccc score is 0.42208845483215474 l1 error is 0.10064993214110865
# classical monocyte's ccc score is 0.4256890475460937 l1 error is 0.1774143742808783
# myeloid cell's ccc score is 0.5634438953491322 l1 error is 0.10252680901559395
# B cell's ccc score is 0.7841572353768973 l1 error is 0.1083668931508885
# T cell's ccc score is 0.00969002795790886 l1 error is 0.04081310779144856
# natural killer cell's ccc score is 0.34851194891409587 l1 error is 0.008955278555345433
# leukocyte's ccc score is 0.7824486429743425 l1 error is 0.07197022878814606
# ciliated columnar cell of tracheobronchial tree's ccc score is 0.7929677453620221 l1 error is 0.004160551615319215
# #################################################################################
# ################## Evaluating DWLS's prediction of Marrow (umi2counts) ##################
# #################################################################################
# Overall ccc score is 0.9111503082917741
# Overall L1 error is 0.04395969612670804
# hematopoietic precursor cell's ccc score is 0.08680655920879368 l1 error is 0.012184330040219585
# granulocyte's ccc score is 0.9609086776839634 l1 error is 0.029722025063764885
# immature B cell's ccc score is 0.7239437691519471 l1 error is 0.1248888850277473
# monocyte's ccc score is 0.21304099892999973 l1 error is 0.016000590998310495
# macrophage's ccc score is 0.9626307487781697 l1 error is 0.029205966988072603
# basophil's ccc score is 0.9046330257882294 l1 error is 0.05175637864213333
# #################################################################################
# ################## Evaluating DWLS's prediction of Marrow (counts2umi) ##################
# #################################################################################
# Overall ccc score is 0.35455039266985444
# Overall L1 error is 0.13457949543369044
# hematopoietic precursor cell's ccc score is 0.004497106555902201 l1 error is 0.09873286809680788
# granulocyte's ccc score is 0.18326895986775843 l1 error is 0.31945020654515954
# immature B cell's ccc score is 0.4091986796355333 l1 error is 0.13975527454168096
# monocyte's ccc score is 0.031298592728753204 l1 error is 0.02565551306733146
# macrophage's ccc score is 0.5044409161526051 l1 error is 0.11187981758416671
# basophil's ccc score is 0.3463335391964265 l1 error is 0.11200329276699625

# %%
pd.read_csv('./DWLS/rare/'+name+'_'+task+'_pred.csv')
# Out:
#                                solDWLS  solDWLS.1  solDWLS.2  solDWLS.3  \
# hematopoietic.precursor.cell  0.048553   0.080442   0.065969   0.058561
# granulocyte                   0.580209   0.298096   0.679533   0.759457
# immature.B.cell               0.066148   0.046502   0.015922   0.065813
# late.pro.B.cell               0.030947   0.000084   0.041591   0.025129
# monocyte                      0.235345   0.201026   0.010703   0.017160
# macrophage                    0.038789   0.286691   0.125256   0.015100
# basophil                      0.000009   0.087159   0.061026   0.058781
#
#                               solDWLS.4  solDWLS.5  solDWLS.6  solDWLS.7  \
# hematopoietic.precursor.cell   0.046928   0.168983   0.037849   0.003968
# granulocyte                    0.679241   0.223596   0.743070   0.109716
# immature.B.cell                0.003703   0.063769   0.038480   0.012738
# late.pro.B.cell                0.027027   0.144329   0.101177   0.540570
# monocyte                       0.020958   0.118049   0.009122   0.037134
# macrophage                     0.151676   0.261265   0.011847   0.232378
# basophil                       0.070467   0.020010   0.058455   0.063496
#
#                               solDWLS.8  solDWLS.9  ...  solDWLS.90  \
# hematopoietic.precursor.cell   0.043610   0.318990  ...    0.044960
# granulocyte                    0.838498   0.102412  ...    0.315632
# immature.B.cell                0.015875   0.018698  ...    0.104551
# late.pro.B.cell                0.011530   0.010790  ...    0.109537
# monocyte                       0.009004   0.021260  ...    0.218972
# macrophage                     0.051527   0.320537  ...    0.109236
# basophil                       0.029957   0.207313  ...    0.097112
#
#                               solDWLS.91  solDWLS.92  solDWLS.93  solDWLS.94  \
# hematopoietic.precursor.cell    0.051434    0.031635    0.000880    0.376430
# granulocyte                     0.601055    0.651090    0.521821    0.220423
# immature.B.cell                 0.011660    0.041829    0.018768    0.007160
# late.pro.B.cell                 0.184038    0.105455    0.359683    0.131509
# monocyte                        0.008677    0.014409    0.008801    0.030226
# macrophage                      0.108583    0.144104    0.037217    0.006580
# basophil                        0.034553    0.011478    0.052830    0.227672
#
#                               solDWLS.95  solDWLS.96  solDWLS.97  solDWLS.98  \
# hematopoietic.precursor.cell    0.070748    0.079038    0.084164    0.375223
# granulocyte                     0.533838    0.567403    0.709829    0.258440
# immature.B.cell                 0.050688    0.032463    0.044652    0.045324
# late.pro.B.cell                 0.197644    0.113423    0.032016    0.094774
# monocyte                        0.008970    0.005767    0.008909    0.026484
# macrophage                      0.133650    0.133137    0.039161    0.054954
# basophil                        0.004464    0.068770    0.081270    0.144802
#
#                               solDWLS.99
# hematopoietic.precursor.cell    0.000003
# granulocyte                     0.817777
# immature.B.cell                 0.005933
# late.pro.B.cell                 0.120758
# monocyte                        0.006045
# macrophage                      0.040088
# basophil                        0.009397
#
# [7 rows x 100 columns]

# %%
### rare
names = ['Limb_Muscle','Lung','Marrow']
tasks = ['counts2umi','umi2counts']
for name in names:
    for task in tasks:
        print('#################################################################################')
        print("################## Evaluating CSx's prediction of "+name+' ('+task+") ##################")
        print('#################################################################################')
        pred = pd.read_csv('./CSx/rare/'+name+'_'+task+'_pred.csv',index_col=0)
        label = pd.read_csv('./TabularMuris/rare/'+name+'_pseudobulk_'+task.split('2')[-1]+'_label.txt',sep='\t',index_col=0)
        inter = pred.columns.intersection(label.columns)
        label = label[inter]
        pred = pred[inter]
        overall_ccc = CCCscore(label.values,pred.values)
        overall_l1 = L1error(label.values,pred.values)
        print('Overall ccc score is',overall_ccc)
        print('Overall L1 error is',overall_l1)
        if name == 'Limb_Muscle':
            rare = rare_celltype_lm
        elif name == 'Lung':
            rare = rare_celltype_lung
        elif name == 'Marrow':
            rare = rare_celltype_marrow
        
        for i in range(pred.shape[1]):
            score = CCCscore(label.iloc[:,i].values,pred.iloc[:,i].values)
            error = L1error(label.iloc[:,i].values,pred.iloc[:,i].values)
            celltype = pred.columns[i]
            if celltype in rare:
                abundant = 'rare'
            else:
                abundant = 'normal'
            print(celltype+"'s ccc score is",score,"l1 error is",error)
            record = record.append({'CellType':celltype,'CCC':score,'L1error':error,
                                    'DataType':task,'Tissue':name,'Method':'CIBERSORTx','abundant':abundant},ignore_index=True)
# Out:
# #################################################################################
# ################## Evaluating CSx's prediction of Limb_Muscle (counts2umi) ##################
# #################################################################################
# Overall ccc score is 0.16394824115250162
# Overall L1 error is 0.16398322133942456
# skeletal muscle satellite cell's ccc score is 0.00017125712426621344 l1 error is 0.34350993072041086
# mesenchymal stem cell's ccc score is 0.7928481587954801 l1 error is 0.0789087503885278
# endothelial cell's ccc score is 0.013376954396642016 l1 error is 0.10116814691376122
# B cell's ccc score is 0.24921159871105988 l1 error is 0.1662581155070458
# macrophage's ccc score is 0.4186095824274919 l1 error is 0.14612749314254006
# T cell's ccc score is 0.4285769988316785 l1 error is 0.1479268913642616
# #################################################################################
# ################## Evaluating CSx's prediction of Limb_Muscle (umi2counts) ##################
# #################################################################################
# Overall ccc score is 0.5404582219013129
# Overall L1 error is 0.14312403825123104
# skeletal muscle satellite cell's ccc score is 0.07477874296579447 l1 error is 0.03454945645345927
# mesenchymal stem cell's ccc score is 0.6771923420336917 l1 error is 0.1832970031308506
# endothelial cell's ccc score is 0.01039752202664434 l1 error is 0.20256880238235492
# B cell's ccc score is 0.41405003565250276 l1 error is 0.17527201031288428
# macrophage's ccc score is 0.6432813044335948 l1 error is 0.11230225990050516
# T cell's ccc score is 0.38644740052333165 l1 error is 0.1507546973273319
# #################################################################################
# ################## Evaluating CSx's prediction of Lung (counts2umi) ##################
# #################################################################################
# Overall ccc score is 0.6362146379998546
# Overall L1 error is 0.07738669672177309
# lung endothelial cell's ccc score is 0.5810755531624389 l1 error is 0.1609167458405383
# stromal cell's ccc score is 0.6681869204437147 l1 error is 0.11822961532204687
# classical monocyte's ccc score is 0.2951527114006952 l1 error is 0.09301086736606377
# myeloid cell's ccc score is 0.5985905616251247 l1 error is 0.06361772932906193
# B cell's ccc score is 0.4938793515314935 l1 error is 0.11338080966680181
# T cell's ccc score is 0.02839598456660946 l1 error is 0.024689450046535107
# natural killer cell's ccc score is 0.10963712893222331 l1 error is 0.03465044422516263
# leukocyte's ccc score is 0.4476331361985399 l1 error is 0.07927471769299523
# ciliated columnar cell of tracheobronchial tree's ccc score is 0.26654667167249274 l1 error is 0.00870989100675206
# #################################################################################
# ################## Evaluating CSx's prediction of Lung (umi2counts) ##################
# #################################################################################
# Overall ccc score is 0.4543194657562101
# Overall L1 error is 0.09489852796189227
# lung endothelial cell's ccc score is 0.9574819609894651 l1 error is 0.0291834237237858
# stromal cell's ccc score is 0.5679231728711203 l1 error is 0.16012397224845182
# classical monocyte's ccc score is 0.14966820249126458 l1 error is 0.1509129747694858
# myeloid cell's ccc score is 0.5265634712352982 l1 error is 0.07268483655692622
# B cell's ccc score is 0.06644705450418394 l1 error is 0.12788856773593976
# T cell's ccc score is 0.0069118842971001146 l1 error is 0.0878985552239902
# natural killer cell's ccc score is 0.008629595737295345 l1 error is 0.13356278933746696
# leukocyte's ccc score is 0.5785982783603619 l1 error is 0.07751722826312973
# ciliated columnar cell of tracheobronchial tree's ccc score is 0.30939103590399886 l1 error is 0.014314403797854145
# #################################################################################
# ################## Evaluating CSx's prediction of Marrow (counts2umi) ##################
# #################################################################################
# Overall ccc score is 0.5405585190384286
# Overall L1 error is 0.10349459823591267
# hematopoietic precursor cell's ccc score is 0.013746026748702574 l1 error is 0.1237969819365989
# granulocyte's ccc score is 0.48584383798116065 l1 error is 0.1878916082621789
# immature B cell's ccc score is 0.5522221270835355 l1 error is 0.09384715843444638
# late pro-B cell's ccc score is 0.8987554341021313 l1 error is 0.04369920494040245
# monocyte's ccc score is 0.12724358232653374 l1 error is 0.02724131505547857
# macrophage's ccc score is 0.591736788977285 l1 error is 0.09646430160656706
# basophil's ccc score is 0.10818313653480581 l1 error is 0.15152161741571632
# #################################################################################
# ################## Evaluating CSx's prediction of Marrow (umi2counts) ##################
# #################################################################################
# Overall ccc score is 0.23413688664704288
# Overall L1 error is 0.1314665862459299
# hematopoietic precursor cell's ccc score is 0.006717656842952333 l1 error is 0.1190690550572035
# granulocyte's ccc score is 0.6595229095671451 l1 error is 0.07524150266907274
# immature B cell's ccc score is 0.0653744675356554 l1 error is 0.1803102827986879
# late pro-B cell's ccc score is 0.8260825735053972 l1 error is 0.0736619864367138
# monocyte's ccc score is 0.0022366488582758757 l1 error is 0.24617812745555168
# macrophage's ccc score is 0.8332359974841957 l1 error is 0.060493311206548175
# basophil's ccc score is 0.2830737309611907 l1 error is 0.16531183809773173

# %%
### rare
names = ['Limb_Muscle','Lung','Marrow']
tasks = ['counts2umi','umi2counts']
for name in names:
    for task in tasks:
        print('#################################################################################')
        print("################## Evaluating Scaden's prediction of "+name+' ('+task+") ##################")
        print('#################################################################################')
        pred = pd.read_csv('./Scaden/rare/'+name+'_'+task+'_pred.txt',index_col=0,sep='\t')
        label = pd.read_csv('./TabularMuris/rare/'+name+'_pseudobulk_'+task.split('2')[-1]+'_label.txt',sep='\t',index_col=0)
        inter = pred.columns.intersection(label.columns)
        label = label[inter]
        pred = pred[inter]
        overall_ccc = CCCscore(label.values,pred.values)
        overall_l1 = L1error(label.values,pred.values)
        print('Overall ccc score is',overall_ccc)
        print('Overall L1 error is',overall_l1)
        if name == 'Limb_Muscle':
            rare = rare_celltype_lm
        elif name == 'Lung':
            rare = rare_celltype_lung
        elif name == 'Marrow':
            rare = rare_celltype_marrow
        
        for i in range(pred.shape[1]):
            score = CCCscore(label.iloc[:,i].values,pred.iloc[:,i].values)
            error = L1error(label.iloc[:,i].values,pred.iloc[:,i].values)
            celltype = pred.columns[i]
            if celltype in rare:
                abundant = 'rare'
            else:
                abundant = 'normal'
            print(celltype+"'s ccc score is",score,"l1 error is",error)
            record = record.append({'CellType':celltype,'CCC':score,'L1error':error,
                                    'DataType':task,'Tissue':name,'Method':'Scaden','abundant':abundant},ignore_index=True)
# Out:
# #################################################################################
# ################## Evaluating Scaden's prediction of Limb_Muscle (counts2umi) ##################
# #################################################################################
# Overall ccc score is 0.6643552652735168
# Overall L1 error is 0.09467162300027553
# mesenchymal stem cell's ccc score is 0.5976401706998938 l1 error is 0.10240715073076295
# skeletal muscle satellite cell's ccc score is 0.008383700762434318 l1 error is 0.0788344138142345
# T cell's ccc score is 0.5515606054205789 l1 error is 0.09703507274064627
# macrophage's ccc score is 0.6374508106927168 l1 error is 0.10208577211664029
# B cell's ccc score is 0.5464776572491933 l1 error is 0.10250276852332726
# endothelial cell's ccc score is 0.013106564374480103 l1 error is 0.0851645600760418
# #################################################################################
# ################## Evaluating Scaden's prediction of Limb_Muscle (umi2counts) ##################
# #################################################################################
# Overall ccc score is 0.7557900459129553
# Overall L1 error is 0.08972396430210373
# mesenchymal stem cell's ccc score is 0.7653590631689795 l1 error is 0.13772202306188785
# skeletal muscle satellite cell's ccc score is 0.18820664307770116 l1 error is 0.02707422518671303
# T cell's ccc score is 0.7426992903585786 l1 error is 0.0944644948405245
# macrophage's ccc score is 0.550109554428985 l1 error is 0.10881717642890014
# B cell's ccc score is 0.48865693297102913 l1 error is 0.1464206331902701
# endothelial cell's ccc score is 0.2412234676551444 l1 error is 0.023845233104326707
# #################################################################################
# ################## Evaluating Scaden's prediction of Lung (counts2umi) ##################
# #################################################################################
# Overall ccc score is 0.5304639638280264
# Overall L1 error is 0.07370618597257113
# myeloid cell's ccc score is 0.39836191133426324 l1 error is 0.07388670342814495
# T cell's ccc score is 0.019588896117340056 l1 error is 0.05494780797512984
# classical monocyte's ccc score is 0.516489401903835 l1 error is 0.08063766818528487
# leukocyte's ccc score is 0.47476183440859404 l1 error is 0.0789331301198035
# natural killer cell's ccc score is 0.007155222455008888 l1 error is 0.08446535179964222
# ciliated columnar cell of tracheobronchial tree's ccc score is 0.08265081723295674 l1 error is 0.03718605314347997
# B cell's ccc score is 0.3613990652947562 l1 error is 0.11165164597776829
# stromal cell's ccc score is 0.38872434476135914 l1 error is 0.08308492527231531
# lung endothelial cell's ccc score is 0.7150791313915935 l1 error is 0.05856238785157112
# #################################################################################
# ################## Evaluating Scaden's prediction of Lung (umi2counts) ##################
# #################################################################################
# Overall ccc score is 0.5509407734018099
# Overall L1 error is 0.08200260592340387
# myeloid cell's ccc score is 0.2469809934703016 l1 error is 0.08761068530759779
# T cell's ccc score is 0.0379411992170571 l1 error is 0.08288567390809222
# classical monocyte's ccc score is 0.6335862778877664 l1 error is 0.07746868538981623
# leukocyte's ccc score is 0.2397956463996429 l1 error is 0.10976508377684523
# natural killer cell's ccc score is 0.3267757313204184 l1 error is 0.009983717019983612
# ciliated columnar cell of tracheobronchial tree's ccc score is 0.2134952290872367 l1 error is 0.01189529157764226
# B cell's ccc score is 0.1659022977067899 l1 error is 0.11335581953297691
# stromal cell's ccc score is 0.4772133032723363 l1 error is 0.18911706736715572
# lung endothelial cell's ccc score is 0.8014595294372596 l1 error is 0.055941429430524804
# #################################################################################
# ################## Evaluating Scaden's prediction of Marrow (counts2umi) ##################
# #################################################################################
# Overall ccc score is 0.7498031474585035
# Overall L1 error is 0.06761646830050556
# immature B cell's ccc score is 0.6176601289912481 l1 error is 0.08494380753529338
# granulocyte's ccc score is 0.755670337703556 l1 error is 0.07801339635392102
# late pro-B cell's ccc score is 0.7920491438865337 l1 error is 0.056669937759210705
# macrophage's ccc score is 0.6878965674044227 l1 error is 0.07325163142054103
# monocyte's ccc score is 0.017404975317354222 l1 error is 0.07622088040124025
# hematopoietic precursor cell's ccc score is 0.06060204390720943 l1 error is 0.03260670560009894
# basophil's ccc score is 0.5503555082823719 l1 error is 0.07160891903323367
# #################################################################################
# ################## Evaluating Scaden's prediction of Marrow (umi2counts) ##################
# #################################################################################
# Overall ccc score is 0.33472723925987563
# Overall L1 error is 0.10989720296122747
# immature B cell's ccc score is 0.210316092662602 l1 error is 0.13243636272954107
# granulocyte's ccc score is 0.6854403900624264 l1 error is 0.07988546004452166
# late pro-B cell's ccc score is 0.7445752204938583 l1 error is 0.06654962365633893
# macrophage's ccc score is 0.893697607333696 l1 error is 0.05227402886053992
# monocyte's ccc score is 0.11817941552761782 l1 error is 0.032676596469725594
# hematopoietic precursor cell's ccc score is 0.0034713483688107827 l1 error is 0.27068933491142005
# basophil's ccc score is 0.3435126768649243 l1 error is 0.13476901405650515

# %%
### rare
names = ['Limb_Muscle','Lung','Marrow']
tasks = ['counts2umi','umi2counts']
for name in names:
    for task in tasks:
        print('#################################################################################')
        print("################## Evaluating MuSiC's prediction of "+name+' ('+task+") ##################")
        print('#################################################################################')
        pred = pd.read_csv('./MuSiC/rare/'+name+'_'+task+'_pred.csv',index_col=0)
        label = pd.read_csv('./TabularMuris/rare/'+name+'_pseudobulk_'+task.split('2')[-1]+'_label.txt',sep='\t',index_col=0)
        inter = pred.columns.intersection(label.columns)
        label = label[inter]
        pred = pred[inter]
        overall_ccc = CCCscore(label.values,pred.values)
        overall_l1 = L1error(label.values,pred.values)
        print('Overall ccc score is',overall_ccc)
        print('Overall L1 error is',overall_l1)
        if name == 'Limb_Muscle':
            rare = rare_celltype_lm
        elif name == 'Lung':
            rare = rare_celltype_lung
        elif name == 'Marrow':
            rare = rare_celltype_marrow
        
        for i in range(pred.shape[1]):
            score = CCCscore(label.iloc[:,i].values,pred.iloc[:,i].values)
            error = L1error(label.iloc[:,i].values,pred.iloc[:,i].values)
            celltype = pred.columns[i]
            if celltype in rare:
                abundant = 'rare'
            else:
                abundant = 'normal'
            print(celltype+"'s ccc score is",score,"l1 error is",error)
            record = record.append({'CellType':celltype,'CCC':score,'L1error':error,
                                    'DataType':task,'Tissue':name,'Method':'MuSiC','abundant':abundant},ignore_index=True)
# Out:
# #################################################################################
# ################## Evaluating MuSiC's prediction of Limb_Muscle (counts2umi) ##################
# #################################################################################
# Overall ccc score is 0.716275242759457
# Overall L1 error is 0.09245014491597774
# skeletal muscle satellite cell's ccc score is 0.028600676190964732 l1 error is 0.014701482144221218
# mesenchymal stem cell's ccc score is 0.7761861893289466 l1 error is 0.08656730320208654
# endothelial cell's ccc score is 0.2681871630657501 l1 error is 0.015509099398325206
# B cell's ccc score is 0.36728657037755424 l1 error is 0.2368313216200278
# macrophage's ccc score is 0.5730152019820544 l1 error is 0.12293106365737184
# T cell's ccc score is 0.7986351815950237 l1 error is 0.07816059947383394
# #################################################################################
# ################## Evaluating MuSiC's prediction of Limb_Muscle (umi2counts) ##################
# #################################################################################
# Overall ccc score is 0.4503756525158893
# Overall L1 error is 0.16968983544395977
# skeletal muscle satellite cell's ccc score is nan l1 error is 0.013543938523286968
# mesenchymal stem cell's ccc score is 0.6815081273164351 l1 error is 0.19096208199310205
# endothelial cell's ccc score is 0.0070114698288021035 l1 error is 0.19139346985881087
# B cell's ccc score is 0.042982226165096005 l1 error is 0.23218032797606677
# macrophage's ccc score is 0.6107935169455005 l1 error is 0.15967770355138206
# T cell's ccc score is 0.032094325546645604 l1 error is 0.23038149076110995
# #################################################################################
# ################## Evaluating MuSiC's prediction of Lung (counts2umi) ##################
# #################################################################################
# Overall ccc score is 0.8077867444769132
# Overall L1 error is 0.05247841306924345
# lung endothelial cell's ccc score is 0.9618370103853626 l1 error is 0.030224815729847688
# stromal cell's ccc score is 0.48814261803112474 l1 error is 0.08491784895592551
# classical monocyte's ccc score is 0.7832054019769356 l1 error is 0.04864681344880885
# myeloid cell's ccc score is 0.7357357778093793 l1 error is 0.09029560620752129
# B cell's ccc score is 0.9044243438138526 l1 error is 0.05859716823377753
# T cell's ccc score is 0.013994340989251564 l1 error is 0.056469980602509164
# natural killer cell's ccc score is 0.6099727331512773 l1 error is 0.005945732295910516
# leukocyte's ccc score is 0.5027694079324434 l1 error is 0.08766257851046148
# ciliated columnar cell of tracheobronchial tree's ccc score is 0.6123981132444336 l1 error is 0.009545173638429032
# #################################################################################
# ################## Evaluating MuSiC's prediction of Lung (umi2counts) ##################
# #################################################################################
# Overall ccc score is 0.7202260655924995
# Overall L1 error is 0.07517638092389635
# lung endothelial cell's ccc score is 0.6927169301424592 l1 error is 0.13011834710714565
# stromal cell's ccc score is 0.7845520042662749 l1 error is 0.08227595072894962
# classical monocyte's ccc score is 0.6937571610548083 l1 error is 0.1254289377930199
# myeloid cell's ccc score is 0.49719407395213444 l1 error is 0.10730265605587652
# B cell's ccc score is nan l1 error is 0.15212552396616802
# T cell's ccc score is nan l1 error is 0.013704094861907776
# natural killer cell's ccc score is 0.24598205354834926 l1 error is 0.012434094313035464
# leukocyte's ccc score is 0.8986398466871659 l1 error is 0.04503558791700777
# ciliated columnar cell of tracheobronchial tree's ccc score is 0.47595318738059994 l1 error is 0.008162235571956273
# #################################################################################
# ################## Evaluating MuSiC's prediction of Marrow (counts2umi) ##################
# #################################################################################
# Overall ccc score is 0.7742334834950656
# Overall L1 error is 0.06900523132228786
# hematopoietic precursor cell's ccc score is 0.01353070650605225 l1 error is 0.12339557484371673
# granulocyte's ccc score is 0.895353140330364 l1 error is 0.05706810789373926
# immature B cell's ccc score is 0.4789273038575038 l1 error is 0.1271337514160195
# late pro-B cell's ccc score is 0.908528661015185 l1 error is 0.050645596373544766
# monocyte's ccc score is 0.17357219836155788 l1 error is 0.013148359642464628
# macrophage's ccc score is 0.8943647752008567 l1 error is 0.047759755830763355
# basophil's ccc score is 0.7694234256462009 l1 error is 0.06388547325576677
# #################################################################################
# ################## Evaluating MuSiC's prediction of Marrow (umi2counts) ##################
# #################################################################################
# Overall ccc score is 0.5197464628234788
# Overall L1 error is 0.11746615405309882
# hematopoietic precursor cell's ccc score is 9.369418094561673e-05 l1 error is 0.014195573874465598
# granulocyte's ccc score is 0.8112932891655981 l1 error is 0.077386097285088
# immature B cell's ccc score is 0.043629236552437875 l1 error is 0.19453832879787591
# late pro-B cell's ccc score is 0.4838477797184246 l1 error is 0.11375416177175668
# monocyte's ccc score is 0.01664436936554499 l1 error is 0.09459959980653014
# macrophage's ccc score is 0.2692294025337797 l1 error is 0.2634092612412282
# basophil's ccc score is 0.8889537070192083 l1 error is 0.06438005559474722

# %%
### rare
names = ['Limb_Muscle','Lung','Marrow']
tasks = ['counts2umi','umi2counts']
for name in names:
    for task in tasks:
        print('#################################################################################')
        print("################## Evaluating TAPE's prediction of "+name+' ('+task+") ##################")
        print('#################################################################################')
        pred = pd.read_csv('./TAPE/rare/'+name+'_'+task+'_pred.csv',index_col=0)
        label = pd.read_csv('./TabularMuris/rare/'+name+'_pseudobulk_'+task.split('2')[-1]+'_label.txt',sep='\t',index_col=0)
        inter = pred.columns.intersection(label.columns)
        label = label[inter]
        pred = pred[inter]
        overall_ccc = CCCscore(label.values,pred.values)
        overall_l1 = L1error(label.values,pred.values)
        print('Overall ccc score is',overall_ccc)
        print('Overall L1 error is',overall_l1)
        if name == 'Limb_Muscle':
            rare = rare_celltype_lm
        elif name == 'Lung':
            rare = rare_celltype_lung
        elif name == 'Marrow':
            rare = rare_celltype_marrow
        
        for i in range(pred.shape[1]):
            score = CCCscore(label.iloc[:,i].values,pred.iloc[:,i].values)
            error = L1error(label.iloc[:,i].values,pred.iloc[:,i].values)
            celltype = pred.columns[i]
            if celltype in rare:
                abundant = 'rare'
            else:
                abundant = 'normal'
            print(celltype+"'s ccc score is",score,"l1 error is",error)
            record = record.append({'CellType':celltype,'CCC':score,'L1error':error,
                                    'DataType':task,'Tissue':name,'Method':'TAPE','abundant':abundant},ignore_index=True)
# Out:
# #################################################################################
# ################## Evaluating TAPE's prediction of Limb_Muscle (counts2umi) ##################
# #################################################################################
# Overall ccc score is 0.7008579234499881
# Overall L1 error is 0.09231424978057655
# B cell's ccc score is 0.6771016856740762 l1 error is 0.09019884102876473
# T cell's ccc score is 0.7224038273575647 l1 error is 0.08748681156178037
# endothelial cell's ccc score is 0.024953831839014763 l1 error is 0.06496484459604181
# macrophage's ccc score is 0.6870282347011684 l1 error is 0.09085006147190292
# mesenchymal stem cell's ccc score is 0.5446792127745246 l1 error is 0.12675059662073493
# skeletal muscle satellite cell's ccc score is 0.0024194382566504243 l1 error is 0.09363434340423452
# #################################################################################
# ################## Evaluating TAPE's prediction of Limb_Muscle (umi2counts) ##################
# #################################################################################
# Overall ccc score is 0.7740133815924174
# Overall L1 error is 0.08895582236505763
# B cell's ccc score is 0.29157408679934327 l1 error is 0.1894499808629648
# T cell's ccc score is 0.8097267856725934 l1 error is 0.07489246648531556
# endothelial cell's ccc score is 0.05857332799682168 l1 error is 0.013312110343219665
# macrophage's ccc score is 0.7826638404232358 l1 error is 0.099153437409252
# mesenchymal stem cell's ccc score is 0.7678484871857149 l1 error is 0.14365115267930675
# skeletal muscle satellite cell's ccc score is 0.029961781690278064 l1 error is 0.013275786410286969
# #################################################################################
# ################## Evaluating TAPE's prediction of Lung (counts2umi) ##################
# #################################################################################
# Overall ccc score is 0.5315958425991447
# Overall L1 error is 0.0735042799471252
# B cell's ccc score is 0.4166958509739628 l1 error is 0.1061303462677936
# T cell's ccc score is 0.013449906538165128 l1 error is 0.07649871929512982
# ciliated columnar cell of tracheobronchial tree's ccc score is 0.23876148775286893 l1 error is 0.029404948270479965
# classical monocyte's ccc score is 0.512214740738373 l1 error is 0.0855452411111076
# leukocyte's ccc score is 0.4463209459274877 l1 error is 0.07845558142051656
# lung endothelial cell's ccc score is 0.638282859341392 l1 error is 0.06088568784957883
# myeloid cell's ccc score is 0.5360105350425931 l1 error is 0.06365376532028032
# natural killer cell's ccc score is 0.005562434029078634 l1 error is 0.09073604268964221
# stromal cell's ccc score is 0.5305430194895864 l1 error is 0.07022818729959783
# #################################################################################
# ################## Evaluating TAPE's prediction of Lung (umi2counts) ##################
# #################################################################################
# Overall ccc score is 0.5365618110311043
# Overall L1 error is 0.09009292018151455
# B cell's ccc score is 0.270456734440177 l1 error is 0.1082912078858347
# T cell's ccc score is 0.145742799232205 l1 error is 0.011911364848781072
# ciliated columnar cell of tracheobronchial tree's ccc score is 0.03749201094165287 l1 error is 0.09274260817146063
# classical monocyte's ccc score is 0.41453464354008435 l1 error is 0.10458748641275192
# leukocyte's ccc score is 0.10986049676506054 l1 error is 0.1400210232824599
# lung endothelial cell's ccc score is 0.8534127068872653 l1 error is 0.0495689278835077
# myeloid cell's ccc score is 0.3397138641887397 l1 error is 0.1355223848134001
# natural killer cell's ccc score is 0.03915448100389753 l1 error is 0.014072783454682738
# stromal cell's ccc score is 0.5409016501269325 l1 error is 0.15411849488075213
# #################################################################################
# ################## Evaluating TAPE's prediction of Marrow (counts2umi) ##################
# #################################################################################
# Overall ccc score is 0.7293022260866296
# Overall L1 error is 0.06796340996238052
# basophil's ccc score is 0.5512320398950361 l1 error is 0.0717591394778431
# granulocyte's ccc score is 0.8738219118567264 l1 error is 0.04339227558879413
# hematopoietic precursor cell's ccc score is 0.04608616391544428 l1 error is 0.05221199671009895
# immature B cell's ccc score is 0.5600665683403241 l1 error is 0.08967320385755143
# late pro-B cell's ccc score is 0.8837645449520106 l1 error is 0.04512012989489993
# macrophage's ccc score is 0.6471528749067336 l1 error is 0.07985561127623582
# monocyte's ccc score is 0.015533542429671135 l1 error is 0.09373151293124024
# #################################################################################
# ################## Evaluating TAPE's prediction of Marrow (umi2counts) ##################
# #################################################################################
# Overall ccc score is 0.7814288260143253
# Overall L1 error is 0.06212361865020406
# basophil's ccc score is 0.6376670215953593 l1 error is 0.08786748230383502
# granulocyte's ccc score is 0.8799307006200866 l1 error is 0.044204607161514795
# hematopoietic precursor cell's ccc score is 0.04264142532813656 l1 error is 0.046188491191420065
# immature B cell's ccc score is 0.6105652968031509 l1 error is 0.08181771715041862
# late pro-B cell's ccc score is 0.7600271596378523 l1 error is 0.06645264731464459
# macrophage's ccc score is 0.7956985999321634 l1 error is 0.0606761816348698
# monocyte's ccc score is 0.07741611316235716 l1 error is 0.0476582037947256

# %%
names = ['Limb_Muscle','Lung','Marrow']
tasks = ['counts2umi','umi2counts']
for name in names:
    for task in tasks:
        print('#################################################################################')
        print("################## Evaluating RNASieve's prediction of "+name+' ('+task+") ##################")
        print('#################################################################################')
        pred = pd.read_csv('./RNAsieve/rare/'+name+'_'+task+'_pred.csv',index_col=0)
        label = pd.read_csv('./TabularMuris/rare/'+name+'_pseudobulk_'+task.split('2')[-1]+'_label.txt',sep='\t',index_col=0)
        pred.columns = [x.replace("_", " ") for x in pred.columns]
        inter = pred.columns.intersection(label.columns)
        label = label[inter]
        pred = pred[inter]
        overall_ccc = CCCscore(label.values,pred.values)
        overall_l1 = L1error(label.values,pred.values)
        print('Overall ccc score is',overall_ccc)
        print('Overall L1 error is',overall_l1)
        if name == 'Limb_Muscle':
            rare = rare_celltype_lm
        elif name == 'Lung':
            rare = rare_celltype_lung
        elif name == 'Marrow':
            rare = rare_celltype_marrow
        
        for i in range(pred.shape[1]):
            score = CCCscore(label.iloc[:,i].values,pred.iloc[:,i].values)
            error = L1error(label.iloc[:,i].values,pred.iloc[:,i].values)
            celltype = pred.columns[i]
            if celltype in rare:
                abundant = 'rare'
            else:
                abundant = 'normal'
            print(celltype+"'s ccc score is",score,"l1 error is",error)
            record = record.append({'CellType':celltype,'CCC':score,'L1error':error,
                                    'DataType':task,'Tissue':name,'Method':'RNAsieve','abundant':abundant},ignore_index=True)
# Out:
# #################################################################################
# ################## Evaluating RNASieve's prediction of Limb_Muscle (counts2umi) ##################
# #################################################################################
# Overall ccc score is 0.045106405558741514
# Overall L1 error is 0.16873080009160343
# B cell's ccc score is -0.00037588734980622423 l1 error is 0.16133691003836367
# T cell's ccc score is -0.056404160581935765 l1 error is 0.16809842928340976
# endothelial cell's ccc score is 0.002327231031612719 l1 error is 0.10457177257105915
# macrophage's ccc score is 0.00810104333249131 l1 error is 0.18862652109520062
# mesenchymal stem cell's ccc score is -0.08457129397600593 l1 error is 0.20932594219522255
# skeletal muscle satellite cell's ccc score is -0.0019879381804356606 l1 error is 0.18042522536636463
# #################################################################################
# ################## Evaluating RNASieve's prediction of Limb_Muscle (umi2counts) ##################
# #################################################################################
# Overall ccc score is 0.1396121763057255
# Overall L1 error is 0.17042294577249376
# B cell's ccc score is 0.012926342925721073 l1 error is 0.23201999450503333
# T cell's ccc score is -0.05666774166088341 l1 error is 0.18545779050367805
# endothelial cell's ccc score is -0.002961289048680854 l1 error is 0.1504485050649115
# macrophage's ccc score is -0.10145756352223305 l1 error is 0.17669605436648936
# mesenchymal stem cell's ccc score is 0.08358292156707957 l1 error is 0.1998234586076371
# skeletal muscle satellite cell's ccc score is 0.006514987643732272 l1 error is 0.07809187158721322
# #################################################################################
# ################## Evaluating RNASieve's prediction of Lung (counts2umi) ##################
# #################################################################################
# Overall ccc score is 0.042678461315304075
# Overall L1 error is 0.1139462299045573
# B cell's ccc score is 0.025863936885345596 l1 error is 0.1531752630721215
# T cell's ccc score is -0.012277586365788677 l1 error is 0.04216387141806904
# ciliated columnar cell of tracheobronchial tree's ccc score is -0.0006977000266001007 l1 error is 0.19165617002674423
# classical monocyte's ccc score is 0.08309945882577353 l1 error is 0.09467054786762823
# leukocyte's ccc score is 0.019703964364462395 l1 error is 0.146316299714349
# lung endothelial cell's ccc score is -0.07295883671858275 l1 error is 0.115338146445703
# myeloid cell's ccc score is -0.17873828849488904 l1 error is 0.11364059809253328
# natural killer cell's ccc score is 0.007755707403310606 l1 error is 0.016966601677873085
# stromal cell's ccc score is 0.09336901216382312 l1 error is 0.15158857082599428
# #################################################################################
# ################## Evaluating RNASieve's prediction of Lung (umi2counts) ##################
# #################################################################################
# Overall ccc score is 0.1535635358143717
# Overall L1 error is 0.12953037801548684
# B cell's ccc score is 0.013254483008104168 l1 error is 0.1500328452108496
# T cell's ccc score is -0.08233600491768547 l1 error is 0.012302719337378643
# ciliated columnar cell of tracheobronchial tree's ccc score is 0.007512002938236426 l1 error is 0.064412113707208
# classical monocyte's ccc score is -0.02963200397896467 l1 error is 0.1682394107678071
# leukocyte's ccc score is 0.007553053594804766 l1 error is 0.139273085918265
# lung endothelial cell's ccc score is 0.00033565844745803055 l1 error is 0.22787752301022515
# myeloid cell's ccc score is -0.03504597949195949 l1 error is 0.1065825410848176
# natural killer cell's ccc score is -0.005051107170817625 l1 error is 0.053590783932038644
# stromal cell's ccc score is -0.02443187709970838 l1 error is 0.2434623791707916
# #################################################################################
# ################## Evaluating RNASieve's prediction of Marrow (counts2umi) ##################
# #################################################################################
# Overall ccc score is -0.22196036142848866
# Overall L1 error is 0.14533045972863284
# basophil's ccc score is -0.03380478610579887 l1 error is 0.11750322253390504
# granulocyte's ccc score is 0.0617726269235257 l1 error is 0.12015233235047605
# hematopoietic precursor cell's ccc score is -0.00019942690272391883 l1 error is 0.30900787740612035
# immature B cell's ccc score is -0.011664392077105115 l1 error is 0.14229822132162032
# late pro-B cell's ccc score is -0.038123988470665705 l1 error is 0.12369801134468203
# macrophage's ccc score is -0.050729129715979364 l1 error is 0.1308544184713989
# monocyte's ccc score is -0.009686380415446685 l1 error is 0.07379913467222723
# #################################################################################
# ################## Evaluating RNASieve's prediction of Marrow (umi2counts) ##################
# #################################################################################
# Overall ccc score is -0.1318434319799752
# Overall L1 error is 0.15510137763196102
# basophil's ccc score is -0.030548734740445095 l1 error is 0.1951399377877818
# granulocyte's ccc score is 0.08114946366461515 l1 error is 0.13347158387253164
# hematopoietic precursor cell's ccc score is 0.00460762412638118 l1 error is 0.24459390481990487
# immature B cell's ccc score is 0.01753076766237012 l1 error is 0.17736770079258438
# late pro-B cell's ccc score is -0.06398375949448101 l1 error is 0.130583018565753
# macrophage's ccc score is 0.03587853278657603 l1 error is 0.11972182378496848
# monocyte's ccc score is 0.001250582454566773 l1 error is 0.08483167380020287

# %%
names = ['Limb_Muscle','Lung','Marrow']
tasks = ['counts2umi','umi2counts']
for name in names:
    for task in tasks:
        print('#################################################################################')
        print("################## Evaluating Bisque's prediction of "+name+' ('+task+") ##################")
        print('#################################################################################')
        pred = pd.read_csv('./Bisque/rare/'+name+'_'+task+'_pred.csv',index_col=0).T
        label = pd.read_csv('./TabularMuris/rare/'+name+'_pseudobulk_'+task.split('2')[-1]+'_label.txt',sep='\t',index_col=0)
        pred.columns = [x.replace("_", " ") for x in pred.columns]
        inter = pred.columns.intersection(label.columns)
        label = label[inter]
        pred = pred[inter]
        overall_ccc = CCCscore(label.values,pred.values)
        overall_l1 = L1error(label.values,pred.values)
        print('Overall ccc score is',overall_ccc)
        print('Overall L1 error is',overall_l1)
        if name == 'Limb_Muscle':
            rare = rare_celltype_lm
        elif name == 'Lung':
            rare = rare_celltype_lung
        elif name == 'Marrow':
            rare = rare_celltype_marrow
        
        for i in range(pred.shape[1]):
            score = CCCscore(label.iloc[:,i].values,pred.iloc[:,i].values)
            error = L1error(label.iloc[:,i].values,pred.iloc[:,i].values)
            celltype = pred.columns[i]
            if celltype in rare:
                abundant = 'rare'
            else:
                abundant = 'normal'
            print(celltype+"'s ccc score is",score,"l1 error is",error)
            record = record.append({'CellType':celltype,'CCC':score,'L1error':error,
                                    'DataType':task,'Tissue':name,'Method':'Bisque','abundant':abundant},ignore_index=True)
# Out:
# #################################################################################
# ################## Evaluating Bisque's prediction of Limb_Muscle (counts2umi) ##################
# #################################################################################
# Overall ccc score is 0.46339059441980907
# Overall L1 error is 0.13657427064228958
# B cell's ccc score is 0.3673702345183654 l1 error is 0.17141217180053567
# T cell's ccc score is 0.09879098035057535 l1 error is 0.20573876301483085
# endothelial cell's ccc score is -0.008684663572000081 l1 error is 0.0904901658461522
# macrophage's ccc score is 0.4466007306879527 l1 error is 0.1507767109868971
# mesenchymal stem cell's ccc score is 0.6987723070383831 l1 error is 0.10897370991607057
# skeletal muscle satellite cell's ccc score is 0.011306953597514803 l1 error is 0.0920541022892511
# #################################################################################
# ################## Evaluating Bisque's prediction of Limb_Muscle (umi2counts) ##################
# #################################################################################
# Overall ccc score is 0.6284563292756485
# Overall L1 error is 0.12235696287399445
# B cell's ccc score is 0.6941454472744921 l1 error is 0.12177734193830209
# T cell's ccc score is 0.6081634572140582 l1 error is 0.1425151473956853
# endothelial cell's ccc score is 0.013579765321329904 l1 error is 0.13231289802248047
# macrophage's ccc score is 0.746394787733039 l1 error is 0.109840541405929
# mesenchymal stem cell's ccc score is 0.8242205412048572 l1 error is 0.08867235954962069
# skeletal muscle satellite cell's ccc score is 0.005224706539588554 l1 error is 0.13902348893194913
# #################################################################################
# ################## Evaluating Bisque's prediction of Lung (counts2umi) ##################
# #################################################################################
# Overall ccc score is 0.3760672641987135
# Overall L1 error is 0.11229803018072372
# B cell's ccc score is 0.49313144863541797 l1 error is 0.14114586042354277
# T cell's ccc score is -0.0017463916334645284 l1 error is 0.151724307053125
# ciliated columnar cell of tracheobronchial tree's ccc score is 0.044651422855350335 l1 error is 0.08339202862534333
# classical monocyte's ccc score is 0.5725261991404632 l1 error is 0.11356679861497927
# leukocyte's ccc score is 0.6180032482177296 l1 error is 0.08954133460885987
# lung endothelial cell's ccc score is -0.059972789794211626 l1 error is 0.1934873014909662
# myeloid cell's ccc score is 0.5491528083330559 l1 error is 0.09824830264730372
# natural killer cell's ccc score is 0.04766035387403459 l1 error is 0.05902798710963829
# stromal cell's ccc score is 0.6981060295985051 l1 error is 0.0805483510527551
# #################################################################################
# ################## Evaluating Bisque's prediction of Lung (umi2counts) ##################
# #################################################################################
# Overall ccc score is 0.4703103583116362
# Overall L1 error is 0.09822394062229518
# B cell's ccc score is 0.36355906307701785 l1 error is 0.11675945552092674
# T cell's ccc score is 0.00782180475155631 l1 error is 0.08968360231774428
# ciliated columnar cell of tracheobronchial tree's ccc score is 0.022896208660344593 l1 error is 0.08351447072970913
# classical monocyte's ccc score is 0.7734280679538919 l1 error is 0.07760161830133422
# leukocyte's ccc score is 0.6998407788369713 l1 error is 0.0895015988475838
# lung endothelial cell's ccc score is 0.3918013364880222 l1 error is 0.12276452753203708
# myeloid cell's ccc score is 0.4740202568525939 l1 error is 0.1136518076147175
# natural killer cell's ccc score is 0.028035744511760108 l1 error is 0.10475034545198379
# stromal cell's ccc score is 0.5683180076540948 l1 error is 0.08578803928462024
# #################################################################################
# ################## Evaluating Bisque's prediction of Marrow (counts2umi) ##################
# #################################################################################
# Overall ccc score is 0.5235185112711537
# Overall L1 error is 0.12132353313587245
# basophil's ccc score is 0.6720622535602269 l1 error is 0.10753413660233108
# granulocyte's ccc score is 0.7717193149912617 l1 error is 0.09688739503467855
# hematopoietic precursor cell's ccc score is 0.008764512652924474 l1 error is 0.09646131234856765
# immature B cell's ccc score is 0.3962113519421126 l1 error is 0.14905667334366157
# late pro-B cell's ccc score is 0.6609802106419029 l1 error is 0.11225930673438707
# macrophage's ccc score is 0.5073343940820976 l1 error is 0.146301744181295
# monocyte's ccc score is 0.01521184466147792 l1 error is 0.14076416370618622
# #################################################################################
# ################## Evaluating Bisque's prediction of Marrow (umi2counts) ##################
# #################################################################################
# Overall ccc score is 0.60833682977606
# Overall L1 error is 0.10603811477622291
# basophil's ccc score is 0.8380063870835531 l1 error is 0.08867064392298218
# granulocyte's ccc score is 0.7062417973490309 l1 error is 0.11338382047856822
# hematopoietic precursor cell's ccc score is 0.012909716738077587 l1 error is 0.08861122208918239
# immature B cell's ccc score is 0.4594686452049351 l1 error is 0.12501929132887127
# late pro-B cell's ccc score is 0.7626294591236524 l1 error is 0.09292293213942193
# macrophage's ccc score is 0.46156606482968315 l1 error is 0.12549065656632466
# monocyte's ccc score is 0.009360971449697572 l1 error is 0.10816823690820968

# %%
record.to_csv('pseudobulk_rare_result.csv')
