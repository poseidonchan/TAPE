# %%
import numpy as np
import pandas as pd
from TAPE.utils import CCCscore, L1error

# %%
record = pd.DataFrame(columns=['CellType','Method','DataType','Tissue','CCC','L1error'])
overall = pd.DataFrame(columns=['Method','DataType','Tissue','overallCCC','overallMAE'])

# %%
### common
names = ['Limb_Muscle','Lung','Marrow']
tasks = ['umi2counts','counts2umi']
for name in names:
    for task in tasks:
        
        print('#################################################################################')
        print("################## Evaluating DWLS's prediction of "+name+' ('+task+") ##################")
        print('#################################################################################')
        pred = pd.read_csv('./DWLS/common/'+name+'_'+task+'_pred.csv',index_col=0).T
        label = pd.read_csv('./TabularMuris/common/'+name+'_pseudobulk_'+task.split('2')[-1]+'_label.txt',sep='\t',index_col=0)
        pred.columns = [x.replace(".", " ") for x in pred.columns]
        inter = pred.columns.intersection(label.columns)
        label = label[inter]
        pred = pred[inter]
        overall_ccc = CCCscore(label.values,pred.values)
        overall_l1 = L1error(label.values,pred.values)
        print('Overall ccc score is',overall_ccc)
        print('Overall L1 error is',overall_l1)
        overall = overall.append({'Method':'DWLS','DataType':task,
                                  'Tissue':name,'overallCCC':overall_ccc,'overallMAE':overall_l1},ignore_index=True)
        for i in range(pred.shape[1]):
            score = CCCscore(label.iloc[:,i].values,pred.iloc[:,i].values)
            error = L1error(label.iloc[:,i].values,pred.iloc[:,i].values)
            celltype = pred.columns[i]
            print(celltype+"'s ccc score is",score,"l1 error is",error)
            record = record.append({'CellType':celltype,'CCC':score,'L1error':error,
                           'DataType':task,'Tissue':name,'Method':'DWLS'},ignore_index=True)
# Out:
# #################################################################################
# ################## Evaluating DWLS's prediction of Limb_Muscle (umi2counts) ##################
# #################################################################################
# Overall ccc score is 0.8945386707903308
# Overall L1 error is 0.04799754023930173
# skeletal muscle satellite cell's ccc score is 0.9760042875552315 l1 error is 0.026057983287901022
# mesenchymal stem cell's ccc score is 0.9778454798887469 l1 error is 0.026112199123786546
# endothelial cell's ccc score is 0.7354693873778012 l1 error is 0.10981466781134099
# B cell's ccc score is 0.952402609929412 l1 error is 0.03278470382453775
# macrophage's ccc score is 0.9559921471787035 l1 error is 0.027680091369471388
# T cell's ccc score is 0.6998841152112443 l1 error is 0.06553559601877267
# #################################################################################
# ################## Evaluating DWLS's prediction of Limb_Muscle (counts2umi) ##################
# #################################################################################
# Overall ccc score is 0.7272874274757932
# Overall L1 error is 0.07468823379355774
# skeletal muscle satellite cell's ccc score is 0.4425168249334691 l1 error is 0.2100485405021844
# mesenchymal stem cell's ccc score is 0.7605365769715674 l1 error is 0.0607582518269286
# endothelial cell's ccc score is 0.8845251222593106 l1 error is 0.048045415242201184
# B cell's ccc score is 0.896862636373518 l1 error is 0.03544827474662551
# macrophage's ccc score is 0.8929434171323883 l1 error is 0.05150215627476259
# T cell's ccc score is 0.8979150363874929 l1 error is 0.04232676416864416
# #################################################################################
# ################## Evaluating DWLS's prediction of Lung (umi2counts) ##################
# #################################################################################
# Overall ccc score is 0.8386142934195051
# Overall L1 error is 0.04571704333091991
# lung endothelial cell's ccc score is 0.7794864029793158 l1 error is 0.04465987855994524
# stromal cell's ccc score is 0.8750820556017453 l1 error is 0.046645395243603616
# classical monocyte's ccc score is 0.9067242665533088 l1 error is 0.0350567456458215
# myeloid cell's ccc score is 0.635044735323224 l1 error is 0.04800811871229626
# B cell's ccc score is 0.9707197311623216 l1 error is 0.019867106263039228
# T cell's ccc score is 0.8902146296541228 l1 error is 0.043041506610831434
# natural killer cell's ccc score is 0.8456563082498343 l1 error is 0.052485669511726146
# leukocyte's ccc score is 0.8577217206583965 l1 error is 0.048807770699909374
# ciliated columnar cell of tracheobronchial tree's ccc score is 0.4506177922444996 l1 error is 0.07288119873110639
# #################################################################################
# ################## Evaluating DWLS's prediction of Lung (counts2umi) ##################
# #################################################################################
# Overall ccc score is 0.5052266514346486
# Overall L1 error is 0.08319604318760133
# lung endothelial cell's ccc score is 0.7202697312734065 l1 error is 0.040823018984014484
# stromal cell's ccc score is 0.539921590346506 l1 error is 0.07490514445801388
# classical monocyte's ccc score is 0.4224625004595329 l1 error is 0.12944265554966455
# myeloid cell's ccc score is 0.5326819343218965 l1 error is 0.08775090244298679
# B cell's ccc score is 0.6297321792098018 l1 error is 0.08281050298992464
# T cell's ccc score is 0.3019399064796027 l1 error is 0.1775690825526536
# natural killer cell's ccc score is 0.7334437889626839 l1 error is 0.05468011128432648
# leukocyte's ccc score is 0.675869145417575 l1 error is 0.07074973887770074
# ciliated columnar cell of tracheobronchial tree's ccc score is 0.8795449563098584 l1 error is 0.030033231549126845
# #################################################################################
# ################## Evaluating DWLS's prediction of Marrow (umi2counts) ##################
# #################################################################################
# Overall ccc score is 0.7795710182518569
# Overall L1 error is 0.06001309738579431
# hematopoietic precursor cell's ccc score is 0.4415098155849031 l1 error is 0.09883025502924662
# granulocyte's ccc score is 0.8915640094079486 l1 error is 0.04733061471046449
# immature B cell's ccc score is 0.626990229009057 l1 error is 0.117353451000271
# late pro-B cell's ccc score is 0.8124472876954889 l1 error is 0.05781324500098285
# monocyte's ccc score is 0.9442784918891186 l1 error is 0.032146269922310136
# macrophage's ccc score is 0.9343951701811997 l1 error is 0.029640438339497702
# basophil's ccc score is 0.9081488187000529 l1 error is 0.03697740769778734
# #################################################################################
# ################## Evaluating DWLS's prediction of Marrow (counts2umi) ##################
# #################################################################################
# Overall ccc score is 0.4543181763214922
# Overall L1 error is 0.1078439511262394
# hematopoietic precursor cell's ccc score is 0.49688903272730883 l1 error is 0.10200112192055028
# granulocyte's ccc score is 0.23981804274455273 l1 error is 0.15649824410434418
# immature B cell's ccc score is 0.33650508797216966 l1 error is 0.11135889769940305
# late pro-B cell's ccc score is 0.772619972765012 l1 error is 0.0614950920002676
# monocyte's ccc score is 0.5243762681433917 l1 error is 0.1592441210863711
# macrophage's ccc score is 0.4794725711345476 l1 error is 0.0858487942669753
# basophil's ccc score is 0.4875605160575761 l1 error is 0.07846138680576434

# %%
### common
names = ['Limb_Muscle','Marrow','Lung']
tasks = ['counts2umi','umi2counts']
for name in names:
    for task in tasks:
        
        print('#################################################################################')
        print("################## Evaluating CSx's prediction of "+name+' ('+task+") ##################")
        print('#################################################################################')
        pred = pd.read_csv('./CSx/common/'+name+'_'+task+'_pred.csv',index_col=0)
        label = pd.read_csv('./TabularMuris/common/'+name+'_pseudobulk_'+task.split('2')[-1]+'_label.txt',sep='\t',index_col=0)
        inter = pred.columns.intersection(label.columns)
        label = label[inter]
        pred = pred[inter]
        overall_ccc = CCCscore(label.values,pred.values)
        overall_l1 = L1error(label.values,pred.values)
        print('Overall ccc score is',overall_ccc)
        print('Overall L1 error is',overall_l1)
        overall = overall.append({'Method':'CIBERSORTx','DataType':task,
                                  'Tissue':name,'overallCCC':overall_ccc,'overallMAE':overall_l1},ignore_index=True)
        for i in range(pred.shape[1]):
            score = CCCscore(label.iloc[:,i].values,pred.iloc[:,i].values)
            error = L1error(label.iloc[:,i].values,pred.iloc[:,i].values)
            celltype = pred.columns[i]
            print(celltype+"'s ccc score is",score,"l1 error is",error)
            record = record.append({'CellType':celltype,'CCC':score,'L1error':error,
                           'DataType':task,'Tissue':name,'Method':'CIBERSORTx'},ignore_index=True)
# Out:
# #################################################################################
# ################## Evaluating CSx's prediction of Limb_Muscle (counts2umi) ##################
# #################################################################################
# Overall ccc score is 0.47524852966018716
# Overall L1 error is 0.11671005876840368
# skeletal muscle satellite cell's ccc score is 0.3673889361406984 l1 error is 0.24830563123135918
# mesenchymal stem cell's ccc score is 0.8469413224765793 l1 error is 0.0586144758300519
# endothelial cell's ccc score is 0.9032301985008714 l1 error is 0.045233719747675635
# B cell's ccc score is 0.25619895030128503 l1 error is 0.09593787549250456
# macrophage's ccc score is 0.38764713475484636 l1 error is 0.11689441052811295
# T cell's ccc score is 0.17930003486383564 l1 error is 0.13527423978071773
# #################################################################################
# ################## Evaluating CSx's prediction of Limb_Muscle (umi2counts) ##################
# #################################################################################
# Overall ccc score is 0.7152981747576054
# Overall L1 error is 0.08694622603069274
# skeletal muscle satellite cell's ccc score is 0.8551396795360497 l1 error is 0.04760503053927373
# mesenchymal stem cell's ccc score is 0.7680914675405481 l1 error is 0.11951826128884106
# endothelial cell's ccc score is 0.7253529907131867 l1 error is 0.11357487013476421
# B cell's ccc score is 0.5898992649281495 l1 error is 0.09291455396551206
# macrophage's ccc score is 0.5562881647016569 l1 error is 0.08488843698715808
# T cell's ccc score is 0.6379943369157115 l1 error is 0.0631762032686074
# #################################################################################
# ################## Evaluating CSx's prediction of Marrow (counts2umi) ##################
# #################################################################################
# Overall ccc score is 0.5369343725306238
# Overall L1 error is 0.0937025925181088
# hematopoietic precursor cell's ccc score is 0.4504989344059046 l1 error is 0.11963113358491148
# granulocyte's ccc score is 0.4777651917184251 l1 error is 0.17054445748464886
# immature B cell's ccc score is 0.47342938932710377 l1 error is 0.07534216580124328
# late pro-B cell's ccc score is 0.8427015772391613 l1 error is 0.05158682855844236
# monocyte's ccc score is 0.7706918530946278 l1 error is 0.0629281000249551
# macrophage's ccc score is 0.677602849989454 l1 error is 0.06627113135734636
# basophil's ccc score is 0.2023803273027051 l1 error is 0.10961433081521407
# #################################################################################
# ################## Evaluating CSx's prediction of Marrow (umi2counts) ##################
# #################################################################################
# Overall ccc score is 0.42043130678199
# Overall L1 error is 0.10487655498334174
# hematopoietic precursor cell's ccc score is 0.7121110717987827 l1 error is 0.06231027702127724
# granulocyte's ccc score is 0.6678953771818076 l1 error is 0.07072549591909408
# immature B cell's ccc score is 0.2726239971572014 l1 error is 0.09668214935683014
# late pro-B cell's ccc score is 0.7773750759784583 l1 error is 0.06583195293062499
# monocyte's ccc score is 0.23090391268201643 l1 error is 0.2440419928230221
# macrophage's ccc score is 0.7384021477956061 l1 error is 0.05556304350603213
# basophil's ccc score is 0.12388680769958789 l1 error is 0.13898097332651146
# #################################################################################
# ################## Evaluating CSx's prediction of Lung (counts2umi) ##################
# #################################################################################
# Overall ccc score is 0.3522135871310449
# Overall L1 error is 0.09876607686953107
# lung endothelial cell's ccc score is 0.1956804615411041 l1 error is 0.2720651557017597
# stromal cell's ccc score is 0.567332177824051 l1 error is 0.1375690269242812
# classical monocyte's ccc score is 0.41591723331469443 l1 error is 0.07130217645915674
# myeloid cell's ccc score is 0.23596990884334276 l1 error is 0.08505969943436442
# B cell's ccc score is 0.6093534651735037 l1 error is 0.06960945686972031
# T cell's ccc score is 0.396885214874608 l1 error is 0.061083444103128215
# natural killer cell's ccc score is 0.26339704555453436 l1 error is 0.06533754849987762
# leukocyte's ccc score is 0.12896248518525077 l1 error is 0.09608325979472507
# ciliated columnar cell of tracheobronchial tree's ccc score is 0.8546905449543305 l1 error is 0.030784924038766294
# #################################################################################
# ################## Evaluating CSx's prediction of Lung (umi2counts) ##################
# #################################################################################
# Overall ccc score is 0.39422302612347265
# Overall L1 error is 0.09630670904225051
# lung endothelial cell's ccc score is 0.7501919519760237 l1 error is 0.06480169541681222
# stromal cell's ccc score is 0.2983494014724477 l1 error is 0.2328604764313733
# classical monocyte's ccc score is 0.2751312626867051 l1 error is 0.084075376257296
# myeloid cell's ccc score is 0.3301664773576119 l1 error is 0.06308803021777719
# B cell's ccc score is 0.0853768318550444 l1 error is 0.10873081270897372
# T cell's ccc score is 0.7125925724136424 l1 error is 0.05237206736216295
# natural killer cell's ccc score is 0.5934105421410799 l1 error is 0.10574772574573917
# leukocyte's ccc score is 0.1861373433816553 l1 error is 0.0827175314421944
# ciliated columnar cell of tracheobronchial tree's ccc score is 0.3770827399745673 l1 error is 0.07236666579792567

# %%
names = ['Limb_Muscle','Marrow','Lung']
tasks = ['counts2umi','umi2counts']
for name in names:
    for task in tasks:
        
        print('#################################################################################')
        print("################## Evaluating Scaden's prediction of "+name+' ('+task+") ##################")
        print('#################################################################################')
        pred = pd.read_csv('./Scaden/common/'+name+'_'+task+'_pred.txt',index_col=0,sep='\t')
        label = pd.read_csv('./TabularMuris/common/'+name+'_pseudobulk_'+task.split('2')[-1]+'_label.txt',sep='\t',index_col=0)
        inter = pred.columns.intersection(label.columns)
        label = label[inter]
        pred = pred[inter]
        overall_ccc = CCCscore(label.values,pred.values)
        overall_l1 = L1error(label.values,pred.values)
        print('Overall ccc score is',overall_ccc)
        print('Overall L1 error is',overall_l1)
        overall = overall.append({'Method':'Scaden','DataType':task,
                                  'Tissue':name,'overallCCC':overall_ccc,'overallMAE':overall_l1},ignore_index=True)
        for i in range(pred.shape[1]):
            score = CCCscore(label.iloc[:,i].values,pred.iloc[:,i].values)
            error = L1error(label.iloc[:,i].values,pred.iloc[:,i].values)
            celltype = pred.columns[i]
            print(celltype+"'s ccc score is",score,"l1 error is",error)
            record = record.append({'CellType':celltype,'CCC':score,'L1error':error,
                           'DataType':task,'Tissue':name,'Method':'Scaden'},ignore_index=True)
# Out:
# #################################################################################
# ################## Evaluating Scaden's prediction of Limb_Muscle (counts2umi) ##################
# #################################################################################
# Overall ccc score is 0.6799723895954861
# Overall L1 error is 0.06675216614529894
# mesenchymal stem cell's ccc score is 0.7080824079814466 l1 error is 0.05472284832735594
# skeletal muscle satellite cell's ccc score is 0.7422479307745715 l1 error is 0.060362112281272265
# T cell's ccc score is 0.582253307693696 l1 error is 0.06856563809392123
# macrophage's ccc score is 0.6697143228172591 l1 error is 0.0768430517354349
# B cell's ccc score is 0.5480795134070697 l1 error is 0.07620151907341159
# endothelial cell's ccc score is 0.7596602294392828 l1 error is 0.06381782736039773
# #################################################################################
# ################## Evaluating Scaden's prediction of Limb_Muscle (umi2counts) ##################
# #################################################################################
# Overall ccc score is 0.6404920250112583
# Overall L1 error is 0.0834770354980267
# mesenchymal stem cell's ccc score is 0.6347645647250764 l1 error is 0.1386734277782198
# skeletal muscle satellite cell's ccc score is 0.858439365654486 l1 error is 0.05339544392281161
# T cell's ccc score is 0.7567953888382877 l1 error is 0.06016694747010849
# macrophage's ccc score is 0.579971659882278 l1 error is 0.07035209132087597
# B cell's ccc score is 0.3367718536871822 l1 error is 0.1355377429671249
# endothelial cell's ccc score is 0.8781304312381415 l1 error is 0.042736559529019294
# #################################################################################
# ################## Evaluating Scaden's prediction of Marrow (counts2umi) ##################
# #################################################################################
# Overall ccc score is 0.6296771940419169
# Overall L1 error is 0.06644264392744396
# immature B cell's ccc score is 0.5794823002700698 l1 error is 0.07322268296499769
# macrophage's ccc score is 0.7006596281488645 l1 error is 0.05232230586978128
# hematopoietic precursor cell's ccc score is 0.5717364978366629 l1 error is 0.05543170054839006
# granulocyte's ccc score is 0.5518704824546491 l1 error is 0.08963265453863585
# basophil's ccc score is 0.5407772056001973 l1 error is 0.076703475788986
# monocyte's ccc score is 0.6824816628300941 l1 error is 0.06129081163999885
# late pro-B cell's ccc score is 0.7299738842162337 l1 error is 0.056494876141318026
# #################################################################################
# ################## Evaluating Scaden's prediction of Marrow (umi2counts) ##################
# #################################################################################
# Overall ccc score is 0.509264153963827
# Overall L1 error is 0.09208091381034762
# immature B cell's ccc score is 0.19122534170850822 l1 error is 0.09531979296838937
# late pro-B cell's ccc score is 0.740122008963677 l1 error is 0.07430095639514211
# granulocyte's ccc score is 0.6558329795628913 l1 error is 0.0708943121126526
# macrophage's ccc score is 0.8304532054050229 l1 error is 0.053392107680142686
# basophil's ccc score is 0.1496917360819045 l1 error is 0.12432259683902315
# monocyte's ccc score is 0.8979531650922107 l1 error is 0.03911493114309285
# hematopoietic precursor cell's ccc score is 0.3571228053191082 l1 error is 0.1872216995339907
# #################################################################################
# ################## Evaluating Scaden's prediction of Lung (counts2umi) ##################
# #################################################################################
# Overall ccc score is 0.5125378111561595
# Overall L1 error is 0.05650391388290441
# leukocyte's ccc score is 0.4315592836843499 l1 error is 0.059102521572032
# ciliated columnar cell of tracheobronchial tree's ccc score is 0.8834798201299737 l1 error is 0.030399395235354194
# T cell's ccc score is 0.39320167789965643 l1 error is 0.05895732025136895
# lung endothelial cell's ccc score is 0.6793243830446422 l1 error is 0.03823786885959366
# natural killer cell's ccc score is 0.41668868057375325 l1 error is 0.06059872670167466
# classical monocyte's ccc score is 0.4938025251184939 l1 error is 0.07309840189067476
# B cell's ccc score is 0.3870455665256932 l1 error is 0.06135618425380021
# stromal cell's ccc score is 0.43848658174385996 l1 error is 0.06358974789721994
# myeloid cell's ccc score is 0.47512688012955323 l1 error is 0.06319505828442136
# #################################################################################
# ################## Evaluating Scaden's prediction of Lung (umi2counts) ##################
# #################################################################################
# Overall ccc score is 0.461833074645025
# Overall L1 error is 0.0748965109543627
# stromal cell's ccc score is 0.3827259247097866 l1 error is 0.19555775747276072
# lung endothelial cell's ccc score is 0.8207128229307046 l1 error is 0.037037282784768075
# B cell's ccc score is 0.3879671448536056 l1 error is 0.07092430510837078
# classical monocyte's ccc score is 0.5309454554640763 l1 error is 0.05552285097588609
# natural killer cell's ccc score is 0.5328765987054233 l1 error is 0.047316595649921835
# leukocyte's ccc score is 0.34535145499335823 l1 error is 0.06469797135889671
# ciliated columnar cell of tracheobronchial tree's ccc score is 0.18412954720182403 l1 error is 0.07035327274942219
# myeloid cell's ccc score is 0.27841811860698706 l1 error is 0.05140011290736507
# T cell's ccc score is 0.5817838872073791 l1 error is 0.08125844958187281

# %%
names = ['Limb_Muscle','Marrow','Lung']
tasks = ['counts2umi','umi2counts']
for name in names:
    for task in tasks:
        
        print('#################################################################################')
        print("################## Evaluating MuSiC's prediction of "+name+' ('+task+") ##################")
        print('#################################################################################')
        pred = pd.read_csv('./MuSiC/common/'+name+'_'+task+'_pred.csv',index_col=0)
        label = pd.read_csv('./TabularMuris/common/'+name+'_pseudobulk_'+task.split('2')[-1]+'_label.txt',sep='\t',index_col=0)
        inter = pred.columns.intersection(label.columns)
        label = label[inter]
        pred = pred[inter]
        overall_ccc = CCCscore(label.values,pred.values)
        overall_l1 = L1error(label.values,pred.values)
        print('Overall ccc score is',overall_ccc)
        print('Overall L1 error is',overall_l1)
        overall = overall.append({'Method':'MuSiC','DataType':task,
                                  'Tissue':name,'overallCCC':overall_ccc,'overallMAE':overall_l1},ignore_index=True)
        for i in range(pred.shape[1]):
            score = CCCscore(label.iloc[:,i].values,pred.iloc[:,i].values)
            error = L1error(label.iloc[:,i].values,pred.iloc[:,i].values)
            celltype = pred.columns[i]
            print(celltype+"'s ccc score is",score,"l1 error is",error)
            record = record.append({'CellType':celltype,'CCC':score,'L1error':error,
                           'DataType':task,'Tissue':name,'Method':'MuSiC'},ignore_index=True)
# Out:
# #################################################################################
# ################## Evaluating MuSiC's prediction of Limb_Muscle (counts2umi) ##################
# #################################################################################
# Overall ccc score is 0.5221398988451101
# Overall L1 error is 0.09722660156287667
# skeletal muscle satellite cell's ccc score is 0.7665687035436161 l1 error is 0.07168109752104854
# mesenchymal stem cell's ccc score is 0.8614893877931192 l1 error is 0.03937047406629357
# endothelial cell's ccc score is 0.8389577825416294 l1 error is 0.051976909750444014
# B cell's ccc score is 0.2055687750037023 l1 error is 0.2651778827740372
# macrophage's ccc score is 0.6534129359506036 l1 error is 0.07996093025824008
# T cell's ccc score is 0.7459108004297663 l1 error is 0.07519231500719667
# #################################################################################
# ################## Evaluating MuSiC's prediction of Limb_Muscle (umi2counts) ##################
# #################################################################################
# Overall ccc score is 0.34139404294265335
# Overall L1 error is 0.1705815513062258
# skeletal muscle satellite cell's ccc score is 0.057376299026767164 l1 error is 0.14881301061765212
# mesenchymal stem cell's ccc score is 0.7014118060254845 l1 error is 0.12629245962324062
# endothelial cell's ccc score is 0.21749798927322808 l1 error is 0.34963131375004564
# B cell's ccc score is 0.00508966788355735 l1 error is 0.17803470709342162
# macrophage's ccc score is 0.7732442117729611 l1 error is 0.06850571315155307
# T cell's ccc score is nan l1 error is 0.15221210360144194
# #################################################################################
# ################## Evaluating MuSiC's prediction of Marrow (counts2umi) ##################
# #################################################################################
# Overall ccc score is 0.7561548595239097
# Overall L1 error is 0.06664696783369477
# hematopoietic precursor cell's ccc score is 0.5565466311764888 l1 error is 0.11371522903117955
# granulocyte's ccc score is 0.8648931634364192 l1 error is 0.05359450107788821
# immature B cell's ccc score is 0.6442580885675279 l1 error is 0.06885727979355381
# late pro-B cell's ccc score is 0.8763168640796797 l1 error is 0.05350327269707534
# monocyte's ccc score is 0.6911469889137549 l1 error is 0.0719650605895602
# macrophage's ccc score is 0.7826370451250851 l1 error is 0.05776087602084894
# basophil's ccc score is 0.8429878804298598 l1 error is 0.047132555625757286
# #################################################################################
# ################## Evaluating MuSiC's prediction of Marrow (umi2counts) ##################
# #################################################################################
# Overall ccc score is 0.3801189372202612
# Overall L1 error is 0.1292157906035046
# hematopoietic precursor cell's ccc score is 0.003894925333635089 l1 error is 0.14360929731023936
# granulocyte's ccc score is 0.7442884735063418 l1 error is 0.06358888581447235
# immature B cell's ccc score is 0.029127294691228767 l1 error is 0.13187388347214324
# late pro-B cell's ccc score is 0.462263505563708 l1 error is 0.08783031896517375
# monocyte's ccc score is 0.36052717133082146 l1 error is 0.2310904215794432
# macrophage's ccc score is 0.30177326724859 l1 error is 0.1959258432003211
# basophil's ccc score is 0.8644239168104966 l1 error is 0.050591883882739025
# #################################################################################
# ################## Evaluating MuSiC's prediction of Lung (counts2umi) ##################
# #################################################################################
# Overall ccc score is 0.7402574496741555
# Overall L1 error is 0.05113080762290412
# lung endothelial cell's ccc score is 0.9032402878004704 l1 error is 0.030911484187598114
# stromal cell's ccc score is 0.5971116870778383 l1 error is 0.06403979598748953
# classical monocyte's ccc score is 0.75074735228785 l1 error is 0.04284257253789353
# myeloid cell's ccc score is 0.754174814507075 l1 error is 0.07438682611980313
# B cell's ccc score is 0.7771119420458117 l1 error is 0.05809757574641027
# T cell's ccc score is 0.7137343915468362 l1 error is 0.05166574405238416
# natural killer cell's ccc score is 0.5817069957529618 l1 error is 0.04831543256487802
# leukocyte's ccc score is 0.5982497073577389 l1 error is 0.058968888664870066
# ciliated columnar cell of tracheobronchial tree's ccc score is 0.9347853220021873 l1 error is 0.030948948744810176
# #################################################################################
# ################## Evaluating MuSiC's prediction of Lung (umi2counts) ##################
# #################################################################################
# Overall ccc score is 0.4808306295538735
# Overall L1 error is 0.09115091040578652
# lung endothelial cell's ccc score is 0.32342612323480385 l1 error is 0.19719927961070088
# stromal cell's ccc score is 0.7592554603013362 l1 error is 0.0755714798794872
# classical monocyte's ccc score is 0.5909430079089655 l1 error is 0.1051482291451377
# myeloid cell's ccc score is 0.48802004623807954 l1 error is 0.0638742445215344
# B cell's ccc score is nan l1 error is 0.1234990235215076
# T cell's ccc score is nan l1 error is 0.1225437027414633
# natural killer cell's ccc score is 0.8146390060074826 l1 error is 0.046923208578352166
# leukocyte's ccc score is 0.8310493356673329 l1 error is 0.038330870034254574
# ciliated columnar cell of tracheobronchial tree's ccc score is 0.6615291289997539 l1 error is 0.04726815561964081

# %%
names = ['Limb_Muscle','Marrow','Lung']
tasks = ['counts2umi','umi2counts']
for name in names:
    for task in tasks:
        
        print('#################################################################################')
        print("################## Evaluating TAPE's prediction of "+name+' ('+task+") ##################")
        print('#################################################################################')
        pred = pd.read_csv('./TAPE/common/'+name+'_'+task+'_pred.csv',index_col=0)
        label = pd.read_csv('./TabularMuris/common/'+name+'_pseudobulk_'+task.split('2')[-1]+'_label.txt',sep='\t',index_col=0)
        inter = pred.columns.intersection(label.columns)
        label = label[inter]
        pred = pred[inter]
        overall_ccc = CCCscore(label.values,pred.values)
        overall_l1 = L1error(label.values,pred.values)
        print('Overall ccc score is',overall_ccc)
        print('Overall L1 error is',overall_l1)
        overall = overall.append({'Method':'TAPE','DataType':task,
                                  'Tissue':name,'overallCCC':overall_ccc,'overallMAE':overall_l1},ignore_index=True)
        for i in range(pred.shape[1]):
            score = CCCscore(label.iloc[:,i].values,pred.iloc[:,i].values)
            error = L1error(label.iloc[:,i].values,pred.iloc[:,i].values)
            celltype = pred.columns[i]
            print(celltype+"'s ccc score is",score,"l1 error is",error)
            record = record.append({'CellType':celltype,'CCC':score,'L1error':error,
                           'DataType':task,'Tissue':name,'Method':'TAPE'},ignore_index=True)
# Out:
# #################################################################################
# ################## Evaluating TAPE's prediction of Limb_Muscle (counts2umi) ##################
# #################################################################################
# Overall ccc score is 0.751867584624495
# Overall L1 error is 0.06259098550605578
# B cell's ccc score is 0.6212743526877997 l1 error is 0.0831250521361712
# T cell's ccc score is 0.7671570389460269 l1 error is 0.06372248898748112
# endothelial cell's ccc score is 0.826823867380789 l1 error is 0.0528996035984747
# macrophage's ccc score is 0.8032011959700563 l1 error is 0.05780156816798629
# mesenchymal stem cell's ccc score is 0.6588450150742708 l1 error is 0.06121219046459757
# skeletal muscle satellite cell's ccc score is 0.7848693495127242 l1 error is 0.056785009681623755
# #################################################################################
# ################## Evaluating TAPE's prediction of Limb_Muscle (umi2counts) ##################
# #################################################################################
# Overall ccc score is 0.624287411800573
# Overall L1 error is 0.09460585754115343
# B cell's ccc score is 0.25654446144325554 l1 error is 0.15211969562098865
# T cell's ccc score is 0.8230133723426132 l1 error is 0.04934687130444018
# endothelial cell's ccc score is 0.7955022128970235 l1 error is 0.05864953224583891
# macrophage's ccc score is 0.7254693715093633 l1 error is 0.09752229555302035
# mesenchymal stem cell's ccc score is 0.6270881097089719 l1 error is 0.1512243700182198
# skeletal muscle satellite cell's ccc score is 0.7780612756972224 l1 error is 0.05877238050441272
# #################################################################################
# ################## Evaluating TAPE's prediction of Marrow (counts2umi) ##################
# #################################################################################
# Overall ccc score is 0.6699246261937719
# Overall L1 error is 0.06182561747154042
# basophil's ccc score is 0.5768388840579597 l1 error is 0.06674832248760824
# granulocyte's ccc score is 0.6081113156470277 l1 error is 0.08310417468177274
# hematopoietic precursor cell's ccc score is 0.6532971759376649 l1 error is 0.04675328672586356
# immature B cell's ccc score is 0.47933030501920154 l1 error is 0.07316237719757904
# late pro-B cell's ccc score is 0.8491016288441765 l1 error is 0.04657815137426929
# macrophage's ccc score is 0.7442994921836964 l1 error is 0.051377587112284726
# monocyte's ccc score is 0.7035938119489887 l1 error is 0.06505542272140535
# #################################################################################
# ################## Evaluating TAPE's prediction of Marrow (umi2counts) ##################
# #################################################################################
# Overall ccc score is 0.7502277123998063
# Overall L1 error is 0.054048945003830416
# basophil's ccc score is 0.6830130407011156 l1 error is 0.060467854656704734
# granulocyte's ccc score is 0.8447621933815304 l1 error is 0.05045022981205317
# hematopoietic precursor cell's ccc score is 0.49383587303900495 l1 error is 0.0671339533294202
# immature B cell's ccc score is 0.6299279173682557 l1 error is 0.059841223873913156
# late pro-B cell's ccc score is 0.8516082906582952 l1 error is 0.04392097552879357
# macrophage's ccc score is 0.8075637756847256 l1 error is 0.04899101620849342
# monocyte's ccc score is 0.8630913850740166 l1 error is 0.04753736161743472
# #################################################################################
# ################## Evaluating TAPE's prediction of Lung (counts2umi) ##################
# #################################################################################
# Overall ccc score is 0.5382008055790491
# Overall L1 error is 0.05470808668176381
# B cell's ccc score is 0.38826198570907056 l1 error is 0.06509729052735062
# T cell's ccc score is 0.42514416129446464 l1 error is 0.06074967203914725
# ciliated columnar cell of tracheobronchial tree's ccc score is 0.79599379125263 l1 error is 0.03139581003130727
# classical monocyte's ccc score is 0.542775341224658 l1 error is 0.06446397789914657
# leukocyte's ccc score is 0.46089418142744726 l1 error is 0.06145051435163259
# lung endothelial cell's ccc score is 0.7072488239620803 l1 error is 0.03702513998296861
# myeloid cell's ccc score is 0.5411531677517127 l1 error is 0.05823667168431183
# natural killer cell's ccc score is 0.4434674748464586 l1 error is 0.05592766594951762
# stromal cell's ccc score is 0.5282846067488741 l1 error is 0.05802603767049198
# #################################################################################
# ################## Evaluating TAPE's prediction of Lung (umi2counts) ##################
# #################################################################################
# Overall ccc score is 0.5020618350945063
# Overall L1 error is 0.07756001771498111
# B cell's ccc score is 0.3919860038918194 l1 error is 0.07678104734483845
# T cell's ccc score is 0.6079165261322531 l1 error is 0.05667833288331962
# ciliated columnar cell of tracheobronchial tree's ccc score is 0.6100032620863437 l1 error is 0.07519545378158096
# classical monocyte's ccc score is 0.5227888870746557 l1 error is 0.05930439226058543
# leukocyte's ccc score is 0.0660711867917317 l1 error is 0.10447351176219394
# lung endothelial cell's ccc score is 0.6820666220035527 l1 error is 0.07123038660013883
# myeloid cell's ccc score is 0.41461193775290167 l1 error is 0.08441848432373539
# natural killer cell's ccc score is 0.5267861165575053 l1 error is 0.06212921662587858
# stromal cell's ccc score is 0.6348108285731058 l1 error is 0.10782933385255868

# %%
### common
names = ['Limb_Muscle']
tasks = ['counts2umi','umi2counts']
for name in names:
    for task in tasks:
        print('#################################################################################')
        print("################## Evaluating BLADE's prediction of "+name+' ('+task+") ##################")
        print('#################################################################################')
        pred = pd.read_csv('./BLADE/common/'+name+'_'+task+'_pred.csv',index_col=0)
        label = pd.read_csv('./TabularMuris/common/'+name+'_pseudobulk_'+task.split('2')[-1]+'_label.txt',sep='\t',index_col=0)
        inter = pred.columns.intersection(label.columns)
        label = label[inter]
        pred = pred[inter]
        overall_ccc = CCCscore(label.values,pred.values)
        overall_l1 = L1error(label.values,pred.values)
        print('Overall ccc score is',overall_ccc)
        print('Overall L1 error is',overall_l1)
        
        for i in range(pred.shape[1]):
            score = CCCscore(label.iloc[:,i].values,pred.iloc[:,i].values)
            error = L1error(label.iloc[:,i].values,pred.iloc[:,i].values)
            celltype = pred.columns[i]
            print(celltype+"'s ccc score is",score,"l1 error is",error)
            #record = record.append({'CellType':celltype,'CCC':score,'L1error':error,
            #              'DataType':task,'Tissue':name,'Method':'BLADE'},ignore_index=True)
# Out:
# #################################################################################
# ################## Evaluating BLADE's prediction of Limb_Muscle (counts2umi) ##################
# #################################################################################
# Overall ccc score is 0.3041160397621712
# Overall L1 error is 0.11527428200173366
# B cell's ccc score is 0.11184574334123164 l1 error is 0.09343059448061482
# T cell's ccc score is 0.3321711016355366 l1 error is 0.15750539154375393
# endothelial cell's ccc score is 0.43561432929594956 l1 error is 0.13304846119055533
# macrophage's ccc score is 0.27432127703466225 l1 error is 0.09889763601857318
# mesenchymal stem cell's ccc score is 0.041613318808572365 l1 error is 0.09934000577191
# skeletal muscle satellite cell's ccc score is 0.19877252500578793 l1 error is 0.10942360300499462
# #################################################################################
# ################## Evaluating BLADE's prediction of Limb_Muscle (umi2counts) ##################
# #################################################################################
# Overall ccc score is 0.0237021298376885
# Overall L1 error is 0.11573085191913511
# B cell's ccc score is 0.01995488631605164 l1 error is 0.12051557420780755
# T cell's ccc score is -0.005643182389498294 l1 error is 0.09771485272020844
# endothelial cell's ccc score is 0.10690880090425228 l1 error is 0.09909056053983938
# macrophage's ccc score is -0.05496114049980223 l1 error is 0.11878726732005544
# mesenchymal stem cell's ccc score is 0.11851971367944548 l1 error is 0.12806600105668708
# skeletal muscle satellite cell's ccc score is -0.1058108137551216 l1 error is 0.13021085567021273

# %%
names = ['Limb_Muscle','Lung','Marrow']
tasks = ['counts2umi','umi2counts']
for name in names:
    for task in tasks:
        print('#################################################################################')
        print("################## Evaluating RNASieve's prediction of "+name+' ('+task+") ##################")
        print('#################################################################################')
        pred = pd.read_csv('./RNAsieve/common/'+name+'_'+task+'_pred.csv',index_col=0)
        label = pd.read_csv('./TabularMuris/common/'+name+'_pseudobulk_'+task.split('2')[-1]+'_label.txt',sep='\t',index_col=0)
        pred.columns = [x.replace("_", " ") for x in pred.columns]
        inter = pred.columns.intersection(label.columns)
        label = label[inter]
        pred = pred[inter]
        overall_ccc = CCCscore(label.values,pred.values)
        overall_l1 = L1error(label.values,pred.values)
        print('Overall ccc score is',overall_ccc)
        print('Overall L1 error is',overall_l1)
        overall = overall.append({'Method':'RNAsieve','DataType':task,
                                  'Tissue':name,'overallCCC':overall_ccc,'overallMAE':overall_l1},ignore_index=True)
        for i in range(pred.shape[1]):
            score = CCCscore(label.iloc[:,i].values,pred.iloc[:,i].values)
            error = L1error(label.iloc[:,i].values,pred.iloc[:,i].values)
            celltype = pred.columns[i]
            print(celltype+"'s ccc score is",score,"l1 error is",error)
            record = record.append({'CellType':celltype,'CCC':score,'L1error':error,
                           'DataType':task,'Tissue':name,'Method':'RNAsieve'},ignore_index=True)
# Out:
# #################################################################################
# ################## Evaluating RNASieve's prediction of Limb_Muscle (counts2umi) ##################
# #################################################################################
# Overall ccc score is -0.08613166497815543
# Overall L1 error is 0.13975263633385515
# B cell's ccc score is -0.05217479442930318 l1 error is 0.09617921816544626
# T cell's ccc score is 0.007726519834219899 l1 error is 0.11550263546199029
# endothelial cell's ccc score is -0.05833643833594874 l1 error is 0.11583985371479535
# macrophage's ccc score is 0.03394118257843762 l1 error is 0.1338871902102639
# mesenchymal stem cell's ccc score is -0.03978330583066194 l1 error is 0.2523303172890422
# skeletal muscle satellite cell's ccc score is -0.16558016873083345 l1 error is 0.12477660316159296
# #################################################################################
# ################## Evaluating RNASieve's prediction of Limb_Muscle (umi2counts) ##################
# #################################################################################
# Overall ccc score is 0.04957713076792544
# Overall L1 error is 0.17155670760320052
# B cell's ccc score is 0.020870763280518134 l1 error is 0.15172458909865247
# T cell's ccc score is -0.01766664725078846 l1 error is 0.1326706615122065
# endothelial cell's ccc score is -0.03606717062916058 l1 error is 0.22724072726348601
# macrophage's ccc score is 0.007252604410748308 l1 error is 0.12640029706094025
# mesenchymal stem cell's ccc score is -0.008728963555063236 l1 error is 0.2771778858832545
# skeletal muscle satellite cell's ccc score is 0.09222369954084005 l1 error is 0.1141260848006633
# #################################################################################
# ################## Evaluating RNASieve's prediction of Lung (counts2umi) ##################
# #################################################################################
# Overall ccc score is 0.015245605914228277
# Overall L1 error is 0.10400740221121894
# B cell's ccc score is 0.06331259045351673 l1 error is 0.08114017859646624
# T cell's ccc score is -0.0292019430039943 l1 error is 0.07808187690404772
# ciliated columnar cell of tracheobronchial tree's ccc score is 0.010848963380656022 l1 error is 0.129761189367152
# classical monocyte's ccc score is 0.0635805024657339 l1 error is 0.08103500931601833
# leukocyte's ccc score is 0.030085771165892346 l1 error is 0.10809349667130823
# lung endothelial cell's ccc score is -0.02183297741227859 l1 error is 0.07853173466319961
# myeloid cell's ccc score is -0.1478269644286368 l1 error is 0.09644219860540422
# natural killer cell's ccc score is 0.011592621117904116 l1 error is 0.08230027352743495
# stromal cell's ccc score is 0.04888626479008073 l1 error is 0.20068066224993913
# #################################################################################
# ################## Evaluating RNASieve's prediction of Lung (umi2counts) ##################
# #################################################################################
# Overall ccc score is 0.01064119344433963
# Overall L1 error is 0.12530886421334228
# B cell's ccc score is 0.038478237645807004 l1 error is 0.12018393128884793
# T cell's ccc score is -0.0011496985851094565 l1 error is 0.12120520243739387
# ciliated columnar cell of tracheobronchial tree's ccc score is 0.03738432417491863 l1 error is 0.14190255193449502
# classical monocyte's ccc score is -0.016241505758441185 l1 error is 0.11322597618168748
# leukocyte's ccc score is -0.011983341137527392 l1 error is 0.08330808016167845
# lung endothelial cell's ccc score is 0.008528519978759282 l1 error is 0.09554676279514158
# myeloid cell's ccc score is -0.05388845417061391 l1 error is 0.06430162739862683
# natural killer cell's ccc score is -0.035580931753229586 l1 error is 0.07421603386324638
# stromal cell's ccc score is -0.0030923642875014 l1 error is 0.31388961185896297
# #################################################################################
# ################## Evaluating RNASieve's prediction of Marrow (counts2umi) ##################
# #################################################################################
# Overall ccc score is -0.06760948595376821
# Overall L1 error is 0.11849058233751537
# basophil's ccc score is -0.03386470538586542 l1 error is 0.10052988234462447
# granulocyte's ccc score is 0.03185752781216046 l1 error is 0.0937818694474892
# hematopoietic precursor cell's ccc score is -0.044146171479777216 l1 error is 0.20396771724334908
# immature B cell's ccc score is -0.02544273989650925 l1 error is 0.10359387121144012
# late pro-B cell's ccc score is 0.0013849335903377334 l1 error is 0.10813425003400175
# macrophage's ccc score is -0.07496370478850212 l1 error is 0.11098167618650759
# monocyte's ccc score is -0.0537357306885844 l1 error is 0.1084448098951955
# #################################################################################
# ################## Evaluating RNASieve's prediction of Marrow (umi2counts) ##################
# #################################################################################
# Overall ccc score is -0.031799470849238766
# Overall L1 error is 0.13039294759480397
# basophil's ccc score is -0.0378770875421729 l1 error is 0.1395474735565822
# granulocyte's ccc score is 0.03807056197464473 l1 error is 0.17202154511532186
# hematopoietic precursor cell's ccc score is 0.028951522021338445 l1 error is 0.16023138386216357
# immature B cell's ccc score is -0.005757508936284543 l1 error is 0.11113534363100269
# late pro-B cell's ccc score is -0.09801561943499898 l1 error is 0.11993135019338878
# macrophage's ccc score is 0.05239295728428447 l1 error is 0.09208279901336557
# monocyte's ccc score is -0.09088880892278207 l1 error is 0.11780073779180335

# %%
names = ['Limb_Muscle','Lung','Marrow']
tasks = ['counts2umi','umi2counts']
for name in names:
    for task in tasks:
        print('#################################################################################')
        print("################## Evaluating Bisque's prediction of "+name+' ('+task+") ##################")
        print('#################################################################################')
        pred = pd.read_csv('./Bisque/common/'+name+'_'+task+'_pred.csv',index_col=0).T
        label = pd.read_csv('./TabularMuris/common/'+name+'_pseudobulk_'+task.split('2')[-1]+'_label.txt',sep='\t',index_col=0)
        pred.columns = [x.replace("_", " ") for x in pred.columns]
        inter = pred.columns.intersection(label.columns)
        label = label[inter]
        pred = pred[inter]
        overall_ccc = CCCscore(label.values,pred.values)
        overall_l1 = L1error(label.values,pred.values)
        print('Overall ccc score is',overall_ccc)
        print('Overall L1 error is',overall_l1)
        overall = overall.append({'Method':'Bisque','DataType':task,
                                  'Tissue':name,'overallCCC':overall_ccc,'overallMAE':overall_l1},ignore_index=True)
        for i in range(pred.shape[1]):
            score = CCCscore(label.iloc[:,i].values,pred.iloc[:,i].values)
            error = L1error(label.iloc[:,i].values,pred.iloc[:,i].values)
            celltype = pred.columns[i]
            print(celltype+"'s ccc score is",score,"l1 error is",error)
            record = record.append({'CellType':celltype,'CCC':score,'L1error':error,'DataType':task,'Tissue':name,'Method':'Bisque'},ignore_index=True)
# Out:
# #################################################################################
# ################## Evaluating Bisque's prediction of Limb_Muscle (counts2umi) ##################
# #################################################################################
# Overall ccc score is 0.4288483061580557
# Overall L1 error is 0.1313639161719458
# B cell's ccc score is 0.2541713032063255 l1 error is 0.1374000758286966
# T cell's ccc score is -0.008837100162274647 l1 error is 0.1968337030885855
# endothelial cell's ccc score is 0.5265673719970987 l1 error is 0.10705511369946728
# macrophage's ccc score is 0.5596698205267701 l1 error is 0.11389835931116556
# mesenchymal stem cell's ccc score is 0.5899582299300722 l1 error is 0.13003130528486728
# skeletal muscle satellite cell's ccc score is 0.64930882981949 l1 error is 0.10296493981889249
# #################################################################################
# ################## Evaluating Bisque's prediction of Limb_Muscle (umi2counts) ##################
# #################################################################################
# Overall ccc score is 0.040577510303471634
# Overall L1 error is 0.1568633401344293
# B cell's ccc score is -0.007064506160824312 l1 error is 0.20511631301341254
# T cell's ccc score is 0.05816279103704077 l1 error is 0.14772314612794632
# endothelial cell's ccc score is 0.12874011135066507 l1 error is 0.12435673917154574
# macrophage's ccc score is 0.002243262757178382 l1 error is 0.14056174676650704
# mesenchymal stem cell's ccc score is -0.019782771044107327 l1 error is 0.1797408048621974
# skeletal muscle satellite cell's ccc score is -0.021722831412888274 l1 error is 0.14368129086496678
# #################################################################################
# ################## Evaluating Bisque's prediction of Lung (counts2umi) ##################
# #################################################################################
# Overall ccc score is 0.5111034101637131
# Overall L1 error is 0.095446831045892
# B cell's ccc score is 0.627109075392396 l1 error is 0.08972033129051123
# T cell's ccc score is 0.2112185861730496 l1 error is 0.136251974859119
# ciliated columnar cell of tracheobronchial tree's ccc score is 0.7568016813578083 l1 error is 0.06920637795320844
# classical monocyte's ccc score is 0.5996134654180653 l1 error is 0.10445520520902617
# leukocyte's ccc score is 0.7536591174279859 l1 error is 0.0614741145004602
# lung endothelial cell's ccc score is 0.16744718119489177 l1 error is 0.1603679254978342
# myeloid cell's ccc score is 0.6487594018505651 l1 error is 0.0881454056958527
# natural killer cell's ccc score is 0.6190254327947748 l1 error is 0.06690524753359404
# stromal cell's ccc score is 0.6105158860401046 l1 error is 0.08249489687342194
# #################################################################################
# ################## Evaluating Bisque's prediction of Lung (umi2counts) ##################
# #################################################################################
# Overall ccc score is 0.5150665263342571
# Overall L1 error is 0.09305574450402913
# B cell's ccc score is 0.32989179946452163 l1 error is 0.11142865291541942
# T cell's ccc score is 0.5255881541643744 l1 error is 0.08913128377367291
# ciliated columnar cell of tracheobronchial tree's ccc score is 0.6170300789229731 l1 error is 0.07764844895081961
# classical monocyte's ccc score is 0.6811855456203276 l1 error is 0.08106380395086955
# leukocyte's ccc score is 0.5762678869713191 l1 error is 0.09337753821273614
# lung endothelial cell's ccc score is 0.5216312459604896 l1 error is 0.07977636579046811
# myeloid cell's ccc score is 0.2966748329903067 l1 error is 0.12591707538551292
# natural killer cell's ccc score is 0.7172421268768535 l1 error is 0.07726613822124309
# stromal cell's ccc score is 0.3627366757915645 l1 error is 0.10189239333552039
# #################################################################################
# ################## Evaluating Bisque's prediction of Marrow (counts2umi) ##################
# #################################################################################
# Overall ccc score is 0.5321875073687794
# Overall L1 error is 0.11483061201744428
# basophil's ccc score is 0.7072327212093311 l1 error is 0.09450628420712544
# granulocyte's ccc score is 0.7339295172319479 l1 error is 0.09007072421303125
# hematopoietic precursor cell's ccc score is 0.1821336934271977 l1 error is 0.13430900550400873
# immature B cell's ccc score is 0.4191329651831835 l1 error is 0.11078114017894868
# late pro-B cell's ccc score is 0.4665857183276455 l1 error is 0.12636300419954127
# macrophage's ccc score is 0.3753424267921086 l1 error is 0.14603250931007777
# monocyte's ccc score is 0.6748914838316654 l1 error is 0.1017516165093767
# #################################################################################
# ################## Evaluating Bisque's prediction of Marrow (umi2counts) ##################
# #################################################################################
# Overall ccc score is -0.03274640927552879
# Overall L1 error is 0.1492137253329333
# basophil's ccc score is -0.09332153185365537 l1 error is 0.16098010398806437
# granulocyte's ccc score is 0.02468424126373395 l1 error is 0.16209521090044673
# hematopoietic precursor cell's ccc score is 0.22959893869474632 l1 error is 0.11380039900987372
# immature B cell's ccc score is 0.07202819221106403 l1 error is 0.15870595288122083
# late pro-B cell's ccc score is -0.21994161235568035 l1 error is 0.1614027374392479
# macrophage's ccc score is -0.07397318773510408 l1 error is 0.13837313609739246
# monocyte's ccc score is -0.1208180264249962 l1 error is 0.14913853701428725

# %%
record
# Out:
#                            CellType  Method    DataType       Tissue  \
# 0    skeletal muscle satellite cell    DWLS  umi2counts  Limb_Muscle
# 1             mesenchymal stem cell    DWLS  umi2counts  Limb_Muscle
# 2                  endothelial cell    DWLS  umi2counts  Limb_Muscle
# 3                            B cell    DWLS  umi2counts  Limb_Muscle
# 4                        macrophage    DWLS  umi2counts  Limb_Muscle
# ..                              ...     ...         ...          ...
# 303    hematopoietic precursor cell  Bisque  umi2counts       Marrow
# 304                 immature B cell  Bisque  umi2counts       Marrow
# 305                 late pro-B cell  Bisque  umi2counts       Marrow
# 306                      macrophage  Bisque  umi2counts       Marrow
# 307                        monocyte  Bisque  umi2counts       Marrow
#
#           CCC   L1error
# 0    0.976004  0.026058
# 1    0.977845  0.026112
# 2    0.735469  0.109815
# 3    0.952403  0.032785
# 4    0.955992  0.027680
# ..        ...       ...
# 303  0.229599  0.113800
# 304  0.072028  0.158706
# 305 -0.219942  0.161403
# 306 -0.073973  0.138373
# 307 -0.120818  0.149139
#
# [308 rows x 6 columns]

# %%
record.to_csv('pseudobulk_normal_result.csv')

# %%
overall.to_csv('pseudobulk_normal_overall.csv')
