# %%
import numpy as np
import pandas as pd
from TAPE.utils import CCCscore, L1error

# %%
record = pd.DataFrame(columns=['CellType','Method','Dataset','CCC','L1error'])

# %%
### common
names = ['sdy67','monaco','microarray']

for name in names:
        
    print('#################################################################################')
    print("################## Evaluating TAPE's prediction of "+name+ "##################")
    print('#################################################################################')
    pred = pd.read_csv('./TAPE/real/'+name+'_pred.csv',index_col=0)
    label = pd.read_csv('./RealDatasets/'+name+'_truth.csv',index_col=0)
    
    inter = pred.columns.intersection(label.columns)
    label = label[inter]
    pred = pred[inter]
    label = label / label.sum(axis=1).values.reshape(-1,1)
    pred = pred / pred.sum(axis=1).values.reshape(-1,1)

    overall_ccc = CCCscore(label.values,pred.values)
    overall_l1 = L1error(label.values,pred.values)
    print('Overall ccc score is',overall_ccc)
    print('Overall L1 error is',overall_l1)
    for i in range(pred.shape[1]):
        score = CCCscore(label.iloc[:,i].values,pred.iloc[:,i].values)
        error = L1error(label.iloc[:,i].values,pred.iloc[:,i].values)
        celltype = pred.columns[i]
        print(celltype+"'s ccc score is",score,"l1 error is",error)
        record = record.append({'CellType':celltype,'CCC':score,'L1error':error,
                                'Dataset':name,'Method':'TAPE'},ignore_index=True)
# Out:
# #################################################################################
# ################## Evaluating TAPE's prediction of sdy67##################
# #################################################################################
# Overall ccc score is 0.777620051161402
# Overall L1 error is 0.062053980789749746
# Monocytes's ccc score is 0.20758398767691852 l1 error is 0.12545293838899846
# Unknown's ccc score is 0.40514826488937944 l1 error is 0.023516487322982293
# CD4Tcells's ccc score is 0.6267128561105988 l1 error is 0.06176906772997428
# Bcells's ccc score is 0.0411621523517373 l1 error is 0.041575766842044316
# NK's ccc score is 0.23280404302587543 l1 error is 0.04371163079674143
# CD8Tcells's ccc score is 0.31782430943704887 l1 error is 0.07629799365775776
# #################################################################################
# ################## Evaluating TAPE's prediction of monaco##################
# #################################################################################
# Overall ccc score is 0.7358307024498835
# Overall L1 error is 0.04364510719534182
# Monocytes's ccc score is 0.3204531536752421 l1 error is 0.08798682574828108
# Unknown's ccc score is 0.005022239897282396 l1 error is 0.04905610415474319
# CD4Tcells's ccc score is 0.48433104597901444 l1 error is 0.03580340328898978
# Bcells's ccc score is 0.7743721001568544 l1 error is 0.01620330626542767
# NK's ccc score is 0.29032899184010735 l1 error is 0.03538517663894864
# CD8Tcells's ccc score is 0.45154008483596186 l1 error is 0.03743582707566056
# #################################################################################
# ################## Evaluating TAPE's prediction of microarray##################
# #################################################################################
# Overall ccc score is 0.6670997779384553
# Overall L1 error is 0.07782067469797146
# Monocytes's ccc score is 0.2912097831427858 l1 error is 0.15147381103023394
# Unknown's ccc score is -0.10144652467688198 l1 error is 0.06004425223096288
# CD4Tcells's ccc score is 0.46546239045328347 l1 error is 0.10835349865349467
# Bcells's ccc score is 0.40470697879006595 l1 error is 0.03666111923508249
# NK's ccc score is 0.3940239917820722 l1 error is 0.04463803464917702
# CD8Tcells's ccc score is 0.37792251929055637 l1 error is 0.0657533323888778

# %%
### common
names = ['sdy67','monaco','microarray']

for name in names:
        
    print('#################################################################################')
    print("################## Evaluating Scaden's prediction of "+name+ "##################")
    print('#################################################################################')
    pred = pd.read_csv('./Scaden/real/'+name+'_pred.txt',index_col=0,sep='\t')
    label = pd.read_csv('./RealDatasets/'+name+'_truth.csv',index_col=0)
    inter = pred.columns.intersection(label.columns)
    label = label[inter]
    pred = pred[inter]
    label = label / label.sum(axis=1).values.reshape(-1,1)
    pred = pred / pred.sum(axis=1).values.reshape(-1,1)

    overall_ccc = CCCscore(label.values,pred.values)
    overall_l1 = L1error(label.values,pred.values)
    print('Overall ccc score is',overall_ccc)
    print('Overall L1 error is',overall_l1)
    for i in range(pred.shape[1]):
        score = CCCscore(label.iloc[:,i].values,pred.iloc[:,i].values)
        error = L1error(label.iloc[:,i].values,pred.iloc[:,i].values)
        celltype = pred.columns[i]
        print(celltype+"'s ccc score is",score,"l1 error is",error)
        record = record.append({'CellType':celltype,'CCC':score,'L1error':error,
                                'Dataset':name,'Method':'Scaden'},ignore_index=True)
# Out:
# #################################################################################
# ################## Evaluating Scaden's prediction of sdy67##################
# #################################################################################
# Overall ccc score is 0.5850333476177713
# Overall L1 error is 0.08429697917764414
# Monocytes's ccc score is 0.12123688986337232 l1 error is 0.20511744915500826
# Unknown's ccc score is 0.3575456508259157 l1 error is 0.01825201348013276
# CD4Tcells's ccc score is 0.33965246981201314 l1 error is 0.1270810185568543
# Bcells's ccc score is 0.113046646552901 l1 error is 0.025971849130002934
# NK's ccc score is 0.4129717776670163 l1 error is 0.04140941693213759
# CD8Tcells's ccc score is 0.38853302511067067 l1 error is 0.08795012781172899
# #################################################################################
# ################## Evaluating Scaden's prediction of monaco##################
# #################################################################################
# Overall ccc score is 0.49423109176232954
# Overall L1 error is 0.0735277934822771
# Monocytes's ccc score is 0.19597962628928947 l1 error is 0.16729245421727576
# Unknown's ccc score is -0.009246648786545861 l1 error is 0.10724714573452467
# CD4Tcells's ccc score is 0.2420226252330783 l1 error is 0.07181361214333948
# Bcells's ccc score is 0.904979500855778 l1 error is 0.011847113767931053
# NK's ccc score is 0.4109487431590544 l1 error is 0.038239770309315906
# CD8Tcells's ccc score is 0.455439248524654 l1 error is 0.04472666472127579
# #################################################################################
# ################## Evaluating Scaden's prediction of microarray##################
# #################################################################################
# Overall ccc score is 0.7052477776069053
# Overall L1 error is 0.0854225666474809
# Monocytes's ccc score is 0.3825301041717198 l1 error is 0.17245863679948242
# Unknown's ccc score is -0.03458171600298839 l1 error is 0.05066351363402537
# CD4Tcells's ccc score is 0.6776946267568845 l1 error is 0.11922481438271801
# Bcells's ccc score is 0.3892686888798095 l1 error is 0.041720436544158655
# NK's ccc score is 0.49315223701060257 l1 error is 0.05609880693301635
# CD8Tcells's ccc score is 0.6265700208175701 l1 error is 0.07236919159148454

# %%
### common
names = ['sdy67','monaco','microarray']

for name in names:
        
    print('#################################################################################')
    print("################## Evaluating CSx's prediction of "+name+ "##################")
    print('#################################################################################')
    pred = pd.read_csv('./CSx/real/'+name+'_pred.csv',index_col=0)
    label = pd.read_csv('./RealDatasets/'+name+'_truth.csv',index_col=0)
    pred.columns = [x.replace("_", " ") for x in pred.columns]
    inter = pred.columns.intersection(label.columns)
    label = label[inter]
    pred = pred[inter]
    label = label / label.sum(axis=1).values.reshape(-1,1)
    pred = pred / pred.sum(axis=1).values.reshape(-1,1)

    overall_ccc = CCCscore(label.values,pred.values)
    overall_l1 = L1error(label.values,pred.values)
    print('Overall ccc score is',overall_ccc)
    print('Overall L1 error is',overall_l1)
    for i in range(pred.shape[1]):
        score = CCCscore(label.iloc[:,i].values,pred.iloc[:,i].values)
        error = L1error(label.iloc[:,i].values,pred.iloc[:,i].values)
        celltype = pred.columns[i]
        print(celltype+"'s ccc score is",score,"l1 error is",error)
        record = record.append({'CellType':celltype,'CCC':score,'L1error':error,
                                'Dataset':name,'Method':'CIBERSORTx'},ignore_index=True)
# Out:
# #################################################################################
# ################## Evaluating CSx's prediction of sdy67##################
# #################################################################################
# Overall ccc score is 0.44511308781415676
# Overall L1 error is 0.12674164215496903
# Bcells's ccc score is 0.26721965261145414 l1 error is 0.03632108830716241
# CD4Tcells's ccc score is 0.6941133734059387 l1 error is 0.07798886215006785
# CD8Tcells's ccc score is 0.20407345127419751 l1 error is 0.2117934964143656
# Monocytes's ccc score is 0.15235690364909818 l1 error is 0.22733888427459029
# NK's ccc score is 0.12484406065631427 l1 error is 0.08026587962865891
# #################################################################################
# ################## Evaluating CSx's prediction of monaco##################
# #################################################################################
# Overall ccc score is 0.73349965702401
# Overall L1 error is 0.06428311804175325
# Bcells's ccc score is 0.12092630290120158 l1 error is 0.06847459822418651
# CD4Tcells's ccc score is 0.5504369741678727 l1 error is 0.05194308292016562
# CD8Tcells's ccc score is 0.40711423133394653 l1 error is 0.07509409533382515
# Monocytes's ccc score is 0.6751707167210047 l1 error is 0.0650607265385804
# NK's ccc score is 0.24495754407014347 l1 error is 0.06084308719200857
# #################################################################################
# ################## Evaluating CSx's prediction of microarray##################
# #################################################################################
# Overall ccc score is 0.598256594628709
# Overall L1 error is 0.10855551416643289
# Bcells's ccc score is 0.44933235904862695 l1 error is 0.04049140944026637
# CD4Tcells's ccc score is 0.708030093388508 l1 error is 0.08459635900414314
# CD8Tcells's ccc score is 0.13968639837474855 l1 error is 0.1547250173927443
# Monocytes's ccc score is 0.2542870302870023 l1 error is 0.2168131523494985
# NK's ccc score is 0.5881373719236881 l1 error is 0.04615163264551209

# %%
### common
names = ['sdy67','monaco','microarray']

for name in names:
        
    print('#################################################################################')
    print("################## Evaluating RNAsieve's prediction of "+name+ "##################")
    print('#################################################################################')
    pred = pd.read_csv('./RNAsieve/real/'+name+'_pred.csv',index_col=0)
    label = pd.read_csv('./RealDatasets/'+name+'_truth.csv',index_col=0)
    pred.columns = [x.replace("_", " ") for x in pred.columns]
    inter = pred.columns.intersection(label.columns)
    label = label[inter]
    pred = pred[inter]
    label = label / label.sum(axis=1).values.reshape(-1,1)
    pred = pred / pred.sum(axis=1).values.reshape(-1,1)

    overall_ccc = CCCscore(label.values,pred.values)
    overall_l1 = L1error(label.values,pred.values)
    print('Overall ccc score is',overall_ccc)
    print('Overall L1 error is',overall_l1)
    for i in range(pred.shape[1]):
        score = CCCscore(label.iloc[:,i].values,pred.iloc[:,i].values)
        error = L1error(label.iloc[:,i].values,pred.iloc[:,i].values)
        celltype = pred.columns[i]
        print(celltype+"'s ccc score is",score,"l1 error is",error)
        record = record.append({'CellType':celltype,'CCC':score,'L1error':error,
                                'Dataset':name,'Method':'RNAsieve'},ignore_index=True)
# Out:
# #################################################################################
# ################## Evaluating RNAsieve's prediction of sdy67##################
# #################################################################################
# Overall ccc score is -0.24145904996717865
# Overall L1 error is 0.25848640866726946
# Bcells's ccc score is 0.3619555622043822 l1 error is 0.023936231570267263
# CD4Tcells's ccc score is 0.03117084191285468 l1 error is 0.32168664795096974
# CD8Tcells's ccc score is 0.0005393210690332068 l1 error is 0.3005931421469367
# Monocytes's ccc score is 0.09045051132135266 l1 error is 0.27839566219631595
# NK's ccc score is -0.014523866200952609 l1 error is 0.3678203594718577
# #################################################################################
# ################## Evaluating RNAsieve's prediction of monaco##################
# #################################################################################
# Overall ccc score is -0.10962975219953647
# Overall L1 error is 0.19498209002007644
# Bcells's ccc score is 0.10852539043352956 l1 error is 0.05228274684413792
# CD4Tcells's ccc score is nan l1 error is 0.2815206428174017
# CD8Tcells's ccc score is 0.04716081875739108 l1 error is 0.1618242188253836
# Monocytes's ccc score is 0.3363465576844246 l1 error is 0.09034148767459878
# NK's ccc score is 0.004297499475738 l1 error is 0.38894135393886026
# #################################################################################
# ################## Evaluating RNAsieve's prediction of microarray##################
# #################################################################################
# Overall ccc score is -0.31377110550446213
# Overall L1 error is 0.23583086202412584
# Bcells's ccc score is 0.03473168990620866 l1 error is 0.06749137621401131
# CD4Tcells's ccc score is nan l1 error is 0.40615645180515203
# CD8Tcells's ccc score is 0.05575382873819019 l1 error is 0.13884017855890327
# Monocytes's ccc score is 0.21175685950886491 l1 error is 0.056688090394951506
# NK's ccc score is 0.0004072864148828575 l1 error is 0.5099782131476112

# %%
### common
names = ['sdy67','monaco','microarray']

for name in names:
        
    print('#################################################################################')
    print("################## Evaluating MuSiC's prediction of "+name+ "##################")
    print('#################################################################################')
    pred = pd.read_csv('./MuSiC/real/'+name+'_pred_music.csv',index_col=0)
    label = pd.read_csv('./RealDatasets/'+name+'_truth.csv',index_col=0)
    pred.columns = [x.replace("_", " ") for x in pred.columns]
    inter = pred.columns.intersection(label.columns)
    label = label[inter]
    pred = pred[inter]
    label = label / label.sum(axis=1).values.reshape(-1,1)
    pred = pred / pred.sum(axis=1).values.reshape(-1,1)

    overall_ccc = CCCscore(label.values,pred.values)
    overall_l1 = L1error(label.values,pred.values)
    print('Overall ccc score is',overall_ccc)
    print('Overall L1 error is',overall_l1)
    for i in range(pred.shape[1]):
        score = CCCscore(label.iloc[:,i].values,pred.iloc[:,i].values)
        error = L1error(label.iloc[:,i].values,pred.iloc[:,i].values)
        celltype = pred.columns[i]
        print(celltype+"'s ccc score is",score,"l1 error is",error)
        record = record.append({'CellType':celltype,'CCC':score,'L1error':error,
                                'Dataset':name,'Method':'MuSiC'},ignore_index=True)
# Out:
# #################################################################################
# ################## Evaluating MuSiC's prediction of sdy67##################
# #################################################################################
# Overall ccc score is -0.2108737582717519
# Overall L1 error is 0.2954851236337491
# Bcells's ccc score is nan l1 error is 0.04541028503978592
# CD4Tcells's ccc score is nan l1 error is 0.33160531343666727
# CD8Tcells's ccc score is nan l1 error is 0.33385051283236905
# Monocytes's ccc score is 0.46432705396387347 l1 error is 0.0866972180772863
# NK's ccc score is -0.015080514216300574 l1 error is 0.6798622887826373
# #################################################################################
# ################## Evaluating MuSiC's prediction of monaco##################
# #################################################################################
# Overall ccc score is -0.14193867151200695
# Overall L1 error is 0.2670615710732515
# Bcells's ccc score is nan l1 error is 0.10690489669878124
# CD4Tcells's ccc score is nan l1 error is 0.2815206428174017
# CD8Tcells's ccc score is nan l1 error is 0.21303287818884123
# Monocytes's ccc score is 0.5359871055573046 l1 error is 0.06806015874406139
# NK's ccc score is 0.003784785272170729 l1 error is 0.6657892789171717
# #################################################################################
# ################## Evaluating MuSiC's prediction of microarray##################
# #################################################################################
# Overall ccc score is -0.13840168170714875
# Overall L1 error is 0.3379544953721667
# Bcells's ccc score is nan l1 error is 0.08963935247203315
# CD4Tcells's ccc score is nan l1 error is 0.40615645180515203
# CD8Tcells's ccc score is nan l1 error is 0.20430723572003
# Monocytes's ccc score is -0.026962392910342987 l1 error is 0.14587242545195242
# NK's ccc score is 0.0016481893819640817 l1 error is 0.8437970114116657

# %%
### common
names = ['sdy67','monaco','microarray']

for name in names:
        
    print('#################################################################################')
    print("################## Evaluating Bisque's prediction of "+name+ "##################")
    print('#################################################################################')
    pred = pd.read_csv('./Bisque/real/'+name+'_pred.csv',index_col=0).T
    label = pd.read_csv('./RealDatasets/'+name+'_truth.csv',index_col=0)
    pred.columns = [x.replace("_", " ") for x in pred.columns]
    inter = pred.columns.intersection(label.columns)
    label = label[inter]
    pred = pred[inter]
    label = label / label.sum(axis=1).values.reshape(-1,1)
    pred = pred / pred.sum(axis=1).values.reshape(-1,1)

    overall_ccc = CCCscore(label.values,pred.values)
    overall_l1 = L1error(label.values,pred.values)
    print('Overall ccc score is',overall_ccc)
    print('Overall L1 error is',overall_l1)
    for i in range(pred.shape[1]):
        score = CCCscore(label.iloc[:,i].values,pred.iloc[:,i].values)
        error = L1error(label.iloc[:,i].values,pred.iloc[:,i].values)
        celltype = pred.columns[i]
        print(celltype+"'s ccc score is",score,"l1 error is",error)
        record = record.append({'CellType':celltype,'CCC':score,'L1error':error,
                                'Dataset':name,'Method':'Bisque'},ignore_index=True)
# Out:
# #################################################################################
# ################## Evaluating Bisque's prediction of sdy67##################
# #################################################################################
# Overall ccc score is 0.00019827060071106394
# Overall L1 error is 0.2350332554391466
# Bcells's ccc score is -0.01076885020145522 l1 error is 0.15695406466485687
# CD4Tcells's ccc score is -0.05704188910671699 l1 error is 0.3216518388301492
# CD8Tcells's ccc score is -0.06556183873369517 l1 error is 0.33850804340899104
# Monocytes's ccc score is 0.25115876935766673 l1 error is 0.18461275778880193
# NK's ccc score is -0.20007931272284835 l1 error is 0.17343957250293374
# #################################################################################
# ################## Evaluating Bisque's prediction of monaco##################
# #################################################################################
# Overall ccc score is 0.16638187448520184
# Overall L1 error is 0.19770598326589228
# Bcells's ccc score is 0.16955702154655272 l1 error is 0.09442192714747305
# CD4Tcells's ccc score is 0.0597375922163288 l1 error is 0.30352608816049503
# CD8Tcells's ccc score is -0.07205547186122142 l1 error is 0.21860677665347752
# Monocytes's ccc score is 0.34934134119159327 l1 error is 0.1461776103466722
# NK's ccc score is -0.09379331903518004 l1 error is 0.22579751402134388
# #################################################################################
# ################## Evaluating Bisque's prediction of microarray##################
# #################################################################################
# Overall ccc score is 0.4024123777492918
# Overall L1 error is 0.1667373944393863
# Bcells's ccc score is 0.244086651633147 l1 error is 0.10943299896846792
# CD4Tcells's ccc score is 0.30894795525411195 l1 error is 0.29643293328393133
# CD8Tcells's ccc score is 0.2469627179736071 l1 error is 0.20101119881365545
# Monocytes's ccc score is 0.5434039864306235 l1 error is 0.11069392355857541
# NK's ccc score is 0.1521065385870467 l1 error is 0.11611591757230136

# %%
names = ['sdy67','monaco','microarray']

for name in names:
        
    print('#################################################################################')
    print("################## Evaluating DWLS's prediction of "+name+ "##################")
    print('#################################################################################')
    pred = pd.read_csv('./DWLS/real/'+name+'_pred.csv',index_col=0).T
    label = pd.read_csv('./RealDatasets/'+name+'_truth.csv',index_col=0)
    pred.columns = [x.replace(".", " ") for x in pred.columns]
    inter = pred.columns.intersection(label.columns)
    label = label[inter]
    pred = pred[inter]
    label = label / label.sum(axis=1).values.reshape(-1,1)
    pred = pred / pred.sum(axis=1).values.reshape(-1,1)

    overall_ccc = CCCscore(label.values,pred.values)
    overall_l1 = L1error(label.values,pred.values)
    print('Overall ccc score is',overall_ccc)
    print('Overall L1 error is',overall_l1)
    for i in range(pred.shape[1]):
        score = CCCscore(label.iloc[:,i].values,pred.iloc[:,i].values)
        error = L1error(label.iloc[:,i].values,pred.iloc[:,i].values)
        celltype = pred.columns[i]
        print(celltype+"'s ccc score is",score,"l1 error is",error)
        record = record.append({'CellType':celltype,'CCC':score,'L1error':error,
                                'Dataset':name,'Method':'DWLS'},ignore_index=True)
# Out:
# #################################################################################
# ################## Evaluating DWLS's prediction of sdy67##################
# #################################################################################
# Overall ccc score is 0.4781334685444777
# Overall L1 error is 0.12397012454085132
# Bcells's ccc score is 0.594048981118509 l1 error is 0.016290920199902543
# CD4Tcells's ccc score is 0.5279612487192495 l1 error is 0.11199626284438431
# CD8Tcells's ccc score is 0.3448682481092949 l1 error is 0.1789269971770361
# Monocytes's ccc score is 0.15464568197908013 l1 error is 0.256050719303045
# NK's ccc score is 0.3103524543831974 l1 error is 0.05658572317988855
# #################################################################################
# ################## Evaluating DWLS's prediction of monaco##################
# #################################################################################
# Overall ccc score is 0.4559955424983077
# Overall L1 error is 0.1069187862706558
# Bcells's ccc score is 0.1642401252890698 l1 error is 0.0631488123111141
# CD4Tcells's ccc score is 0.21436288171271556 l1 error is 0.1442110666370692
# CD8Tcells's ccc score is 0.4456414613284246 l1 error is 0.07766046153173194
# Monocytes's ccc score is 0.18561141269987272 l1 error is 0.20004409202081744
# NK's ccc score is 0.3472011544433938 l1 error is 0.04952949885254638
# #################################################################################
# ################## Evaluating DWLS's prediction of microarray##################
# #################################################################################
# Overall ccc score is 0.6528319627827175
# Overall L1 error is 0.13555708713058412
# Bcells's ccc score is 0.20976275510206335 l1 error is 0.06951006751355185
# CD4Tcells's ccc score is 0.464979351502063 l1 error is 0.1995856403715737
# CD8Tcells's ccc score is 0.032067362522163204 l1 error is 0.19344926796108874
# Monocytes's ccc score is 0.4331655478784287 l1 error is 0.1508996706213559
# NK's ccc score is 0.6451618553716008 l1 error is 0.06434078918535066

# %%
record.to_csv('PBMCseries_real_result.csv')
