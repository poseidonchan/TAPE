# %%
import numpy as np
import pandas as pd
from TAPE.utils import CCCscore, L1error

# %%
record = pd.DataFrame(columns=['CellType','Method','DataType','MissingCell','CCC','L1error'])

# %%
### missing & similar
tasks = ['counts2umi','umi2counts']
missing_celltypes = ['lpb','ib']
for missing_celltype in missing_celltypes:
    for task in tasks:
        print('#################################################################################')
        print("################## Evaluating DWLS's prediction of "+missing_celltype+' missing ('+task+") ##################")
        print('#################################################################################')
        pred = pd.read_csv('./DWLS/similar/Marrow_'+task+'_'+missing_celltype+'_missing_pred.csv',index_col=0).T
        label = pd.read_csv('./TabularMuris/common/Marrow_pseudobulk_'+task.split('2')[-1]+'_label.txt',sep='\t',index_col=0)
        pred.columns = [x.replace(".", " ") for x in pred.columns]
        label['Bcell_sum'] = label['late pro-B cell']+label['immature B cell']
        
        if missing_celltype == 'lpb':
            pred['Bcell_sum'] = pred['immature B cell']
            pred.drop('immature B cell',inplace=True,axis=1)
        elif missing_celltype == 'ib':
            pred['Bcell_sum'] = pred['late pro B cell']
            pred.drop('late pro B cell',inplace=True,axis=1)
        
        inter = pred.columns.intersection(label.columns)
        label = label[inter]
        pred = pred[inter]
        overall_ccc = CCCscore(label.values,pred.values)
        overall_l1 = L1error(label.values,pred.values)
        print('Overall ccc score is',overall_ccc)
        print('Overall L1 error is',overall_l1)
        for i in range(pred.shape[1]):
            score = CCCscore(label.iloc[:,i].values,pred.iloc[:,i].values)
            error = L1error(label.iloc[:,i].values,pred.iloc[:,i].values)
            celltype = pred.columns[i]
            print(celltype+"'s ccc score is",score,"l1 error is",error)
            record = record.append({'CellType':celltype,'CCC':score,'L1error':error,
                           'DataType':task,'MissingCell':missing_celltype,'Method':'DWLS'},ignore_index=True)
# Out:
# #################################################################################
# ################## Evaluating DWLS's prediction of lpb missing (counts2umi) ##################
# #################################################################################
# Overall ccc score is 0.2519748630206778
# Overall L1 error is 0.14909738151949775
# hematopoietic precursor cell's ccc score is 0.3107238608331995 l1 error is 0.16322229549626144
# granulocyte's ccc score is 0.056566001251268594 l1 error is 0.24652473653230575
# monocyte's ccc score is 0.6620086250265291 l1 error is 0.09691570330517152
# macrophage's ccc score is 0.3828030290192958 l1 error is 0.09401554699834751
# basophil's ccc score is 0.5047764852436746 l1 error is 0.07667533504597586
# Bcell_sum's ccc score is 0.2524931155977122 l1 error is 0.2172306717389244
# #################################################################################
# ################## Evaluating DWLS's prediction of lpb missing (umi2counts) ##################
# #################################################################################
# Overall ccc score is 0.8276235024866048
# Overall L1 error is 0.05733333706098679
# hematopoietic precursor cell's ccc score is 0.28654184513502445 l1 error is 0.12177136807842531
# granulocyte's ccc score is 0.8631601015960537 l1 error is 0.054436758992915786
# monocyte's ccc score is 0.937786737793234 l1 error is 0.03099055027159868
# macrophage's ccc score is 0.9448406788052316 l1 error is 0.02724442860823655
# basophil's ccc score is 0.897471885279012 l1 error is 0.03808033572119039
# Bcell_sum's ccc score is 0.8718583406151623 l1 error is 0.07147658069355403
# #################################################################################
# ################## Evaluating DWLS's prediction of ib missing (counts2umi) ##################
# #################################################################################
# Overall ccc score is 0.31532796665735785
# Overall L1 error is 0.1375088991724235
# hematopoietic precursor cell's ccc score is 0.238142842461991 l1 error is 0.14534517963620747
# granulocyte's ccc score is 0.7190709449600601 l1 error is 0.06978406873704215
# monocyte's ccc score is 0.2920337267322951 l1 error is 0.2604958723019804
# macrophage's ccc score is 0.5800393559353514 l1 error is 0.07358552354627589
# basophil's ccc score is 0.541908046539546 l1 error is 0.07064948822207319
# Bcell_sum's ccc score is 0.24809826837745516 l1 error is 0.20519326259096196
# #################################################################################
# ################## Evaluating DWLS's prediction of ib missing (umi2counts) ##################
# #################################################################################
# Overall ccc score is 0.746778025984423
# Overall L1 error is 0.07500456464401783
# hematopoietic precursor cell's ccc score is 0.31176082595946764 l1 error is 0.12505144054451667
# granulocyte's ccc score is 0.7760132736392338 l1 error is 0.08844838052058178
# monocyte's ccc score is 0.8572597756577454 l1 error is 0.0639728869770276
# macrophage's ccc score is 0.8493004147910755 l1 error is 0.061675085921948786
# basophil's ccc score is 0.9646010883940055 l1 error is 0.023024848191404393
# Bcell_sum's ccc score is 0.7402096909140932 l1 error is 0.08785474570862785

# %%
pred
# Out:
#             hematopoietic precursor cell  granulocyte  monocyte  macrophage  \
# solDWLS                     2.206518e-09     0.161949  0.076499    0.396860
# solDWLS.1                   2.268868e-01     0.271220  0.193519    0.047709
# solDWLS.2                   8.873930e-20     0.187207  0.234310    0.141101
# solDWLS.3                  -6.849473e-21     0.056663  0.048269    0.234730
# solDWLS.4                   2.253037e-22     0.333693  0.087080    0.135424
# ...                                  ...          ...       ...         ...
# solDWLS.95                  2.728728e-03     0.111836  0.299687    0.088205
# solDWLS.96                  6.047287e-23     0.093581  0.349688    0.344452
# solDWLS.97                 -2.225002e-26     0.213949  0.345181    0.292619
# solDWLS.98                  3.787794e-20     0.260328  0.308190    0.141034
# solDWLS.99                  0.000000e+00     0.079665  0.673282    0.172096
#
#             basophil  Bcell_sum
# solDWLS     0.142997   0.221695
# solDWLS.1   0.190652   0.070012
# solDWLS.2   0.267727   0.169655
# solDWLS.3   0.390070   0.270268
# solDWLS.4   0.263421   0.180383
# ...              ...        ...
# solDWLS.95  0.244601   0.252943
# solDWLS.96  0.118788   0.093492
# solDWLS.97  0.004893   0.143359
# solDWLS.98  0.181150   0.109298
# solDWLS.99  0.036889   0.038068
#
# [100 rows x 6 columns]

# %%
### missing & similar
tasks = ['counts2umi','umi2counts']
missing_celltypes = ['lpb','ib']
for missing_celltype in missing_celltypes:
    for task in tasks:
        print('#################################################################################')
        print("################## Evaluating CSx's prediction of "+missing_celltype+' missing ('+task+") ##################")
        print('#################################################################################')
        pred = pd.read_csv('./CSx/similar/Marrow_'+task+'_'+missing_celltype+'_missing_pred.csv',index_col=0)
        label = pd.read_csv('./TabularMuris/common/Marrow_pseudobulk_'+task.split('2')[-1]+'_label.txt',sep='\t',index_col=0)
        label['Bcell_sum'] = label['late pro-B cell']+label['immature B cell']
        
        if missing_celltype == 'lpb':
            pred['Bcell_sum'] = pred['immature B cell']
            pred.drop('immature B cell',inplace=True,axis=1)
        elif missing_celltype == 'ib':
            pred['Bcell_sum'] = pred['late pro-B cell']
            pred.drop('late pro-B cell',inplace=True,axis=1)
        
        inter = pred.columns.intersection(label.columns)
        label = label[inter]
        pred = pred[inter]
        overall_ccc = CCCscore(label.values,pred.values)
        overall_l1 = L1error(label.values,pred.values)
        print('Overall ccc score is',overall_ccc)
        print('Overall L1 error is',overall_l1)
        for i in range(pred.shape[1]):
            score = CCCscore(label.iloc[:,i].values,pred.iloc[:,i].values)
            error = L1error(label.iloc[:,i].values,pred.iloc[:,i].values)
            celltype = pred.columns[i]
            print(celltype+"'s ccc score is",score,"l1 error is",error)
            record = record.append({'CellType':celltype,'CCC':score,'L1error':error,
                           'DataType':task,'MissingCell':missing_celltype,'Method':'CIBERSORTx'},ignore_index=True)
# Out:
# #################################################################################
# ################## Evaluating CSx's prediction of lpb missing (counts2umi) ##################
# #################################################################################
# Overall ccc score is 0.378912036993594
# Overall L1 error is 0.1284371186021278
# hematopoietic precursor cell's ccc score is 0.3005509695812479 l1 error is 0.13757356530006548
# granulocyte's ccc score is 0.3048060793036115 l1 error is 0.2323095043109085
# monocyte's ccc score is 0.7157603464314098 l1 error is 0.07699118866561756
# macrophage's ccc score is 0.745506575826885 l1 error is 0.056149695676604924
# basophil's ccc score is 0.14091639460234834 l1 error is 0.11398527377235514
# Bcell_sum's ccc score is 0.29861570237107354 l1 error is 0.15361348388721519
# #################################################################################
# ################## Evaluating CSx's prediction of lpb missing (umi2counts) ##################
# #################################################################################
# Overall ccc score is 0.21317745096345786
# Overall L1 error is 0.14800653230732125
# hematopoietic precursor cell's ccc score is 0.43608732801356503 l1 error is 0.14888047499280532
# granulocyte's ccc score is 0.6169996666323799 l1 error is 0.0730256516502513
# monocyte's ccc score is 0.20168284432285846 l1 error is 0.27089149034676085
# macrophage's ccc score is 0.701276095464639 l1 error is 0.06606951273824982
# basophil's ccc score is 0.47093552008581646 l1 error is 0.08833974384658962
# Bcell_sum's ccc score is 0.049299860392024386 l1 error is 0.24083232026927068
# #################################################################################
# ################## Evaluating CSx's prediction of ib missing (counts2umi) ##################
# #################################################################################
# Overall ccc score is 0.4817660954446135
# Overall L1 error is 0.11641957950188855
# hematopoietic precursor cell's ccc score is 0.3335425826276768 l1 error is 0.1554801428169713
# granulocyte's ccc score is 0.4338371852947785 l1 error is 0.1805842362124693
# monocyte's ccc score is 0.7125029605729541 l1 error is 0.062982061363466
# macrophage's ccc score is 0.5605909204543176 l1 error is 0.0752035829176083
# basophil's ccc score is 0.27608382081503124 l1 error is 0.10248861051426768
# Bcell_sum's ccc score is 0.5132505220602058 l1 error is 0.12177884318654876
# #################################################################################
# ################## Evaluating CSx's prediction of ib missing (umi2counts) ##################
# #################################################################################
# Overall ccc score is 0.407396608338126
# Overall L1 error is 0.11888419459614459
# hematopoietic precursor cell's ccc score is 0.711709735984698 l1 error is 0.06639937731221915
# granulocyte's ccc score is 0.643010504961726 l1 error is 0.07242051451818568
# monocyte's ccc score is 0.19979147227755314 l1 error is 0.2791300453983739
# macrophage's ccc score is 0.7132683652118375 l1 error is 0.06183162942534736
# basophil's ccc score is 0.2077646846329988 l1 error is 0.12305601310673919
# Bcell_sum's ccc score is 0.5846122002308413 l1 error is 0.11046758781600235

# %%
### missing & similar
tasks = ['counts2umi','umi2counts']
missing_celltypes = ['lpb','ib']
for missing_celltype in missing_celltypes:
    for task in tasks:
        print('#################################################################################')
        print("################## Evaluating Scaden's prediction of "+missing_celltype+' missing ('+task+") ##################")
        print('#################################################################################')
        pred = pd.read_csv('./Scaden/similar/Marrow_'+task+'_'+missing_celltype+'_missing_pred.txt',index_col=0,sep='\t')
        label = pd.read_csv('./TabularMuris/common/Marrow_pseudobulk_'+task.split('2')[-1]+'_label.txt',sep='\t',index_col=0)
        label['Bcell_sum'] = label['late pro-B cell']+label['immature B cell']
        
        if missing_celltype == 'lpb':
            pred['Bcell_sum'] = pred['immature B cell']
            pred.drop('immature B cell',inplace=True,axis=1)
        elif missing_celltype == 'ib':
            pred['Bcell_sum'] = pred['late pro-B cell']
            pred.drop('late pro-B cell',inplace=True,axis=1)
        
        inter = pred.columns.intersection(label.columns)
        label = label[inter]
        pred = pred[inter]
        overall_ccc = CCCscore(label.values,pred.values)
        overall_l1 = L1error(label.values,pred.values)
        print('Overall ccc score is',overall_ccc)
        print('Overall L1 error is',overall_l1)
        for i in range(pred.shape[1]):
            score = CCCscore(label.iloc[:,i].values,pred.iloc[:,i].values)
            error = L1error(label.iloc[:,i].values,pred.iloc[:,i].values)
            celltype = pred.columns[i]
            print(celltype+"'s ccc score is",score,"l1 error is",error)
            record = record.append({'CellType':celltype,'CCC':score,'L1error':error,
                           'DataType':task,'MissingCell':missing_celltype,'Method':'Scaden'},ignore_index=True)
# Out:
# #################################################################################
# ################## Evaluating Scaden's prediction of lpb missing (counts2umi) ##################
# #################################################################################
# Overall ccc score is 0.6235068284436825
# Overall L1 error is 0.07609255520807214
# hematopoietic precursor cell's ccc score is 0.6322801286342727 l1 error is 0.050871817351695346
# macrophage's ccc score is 0.7321068822026273 l1 error is 0.05406032281177143
# granulocyte's ccc score is 0.5643860305498546 l1 error is 0.09010950872572547
# basophil's ccc score is 0.5656758750974001 l1 error is 0.07586981273184314
# monocyte's ccc score is 0.6198451105772361 l1 error is 0.07201224832141637
# Bcell_sum's ccc score is 0.4847337996192537 l1 error is 0.11363162130598108
# #################################################################################
# ################## Evaluating Scaden's prediction of lpb missing (umi2counts) ##################
# #################################################################################
# Overall ccc score is 0.32506099401651595
# Overall L1 error is 0.12124268931179777
# hematopoietic precursor cell's ccc score is 0.1853200897915757 l1 error is 0.3115918444372165
# macrophage's ccc score is 0.8432105418306616 l1 error is 0.05000013403109823
# granulocyte's ccc score is 0.7565919525934884 l1 error is 0.05605095966191115
# basophil's ccc score is 0.2602247596837927 l1 error is 0.10630220193889334
# monocyte's ccc score is 0.8699455909787727 l1 error is 0.03909327598897663
# Bcell_sum's ccc score is 0.24444955307257887 l1 error is 0.16441771981269082
# #################################################################################
# ################## Evaluating Scaden's prediction of ib missing (counts2umi) ##################
# #################################################################################
# Overall ccc score is 0.577798540544952
# Overall L1 error is 0.08334654141770428
# hematopoietic precursor cell's ccc score is 0.5900192211201628 l1 error is 0.05111283358161971
# macrophage's ccc score is 0.7623697499466954 l1 error is 0.051547047284135186
# granulocyte's ccc score is 0.4483036585743137 l1 error is 0.11782010361636505
# basophil's ccc score is 0.522784047464821 l1 error is 0.07772073471184313
# monocyte's ccc score is 0.6077962782604075 l1 error is 0.07654084106479275
# Bcell_sum's ccc score is 0.46758486027583185 l1 error is 0.12533768824746988
# #################################################################################
# ################## Evaluating Scaden's prediction of ib missing (umi2counts) ##################
# #################################################################################
# Overall ccc score is 0.4661957834621438
# Overall L1 error is 0.10433694078788626
# hematopoietic precursor cell's ccc score is 0.2468846193311499 l1 error is 0.2624572120372165
# macrophage's ccc score is 0.8302535863939023 l1 error is 0.04221598610586707
# granulocyte's ccc score is 0.7780619941002221 l1 error is 0.056581012585988785
# basophil's ccc score is 0.207092586594551 l1 error is 0.11889927594951026
# monocyte's ccc score is 0.9030951824999262 l1 error is 0.03957943667975086
# Bcell_sum's ccc score is 0.5436706290846208 l1 error is 0.1062887213689841

# %%
### missing & similar
tasks = ['counts2umi','umi2counts']
missing_celltypes = ['lpb','ib']
for missing_celltype in missing_celltypes:
    for task in tasks:
        print('#################################################################################')
        print("################## Evaluating MuSiC's prediction of "+missing_celltype+' missing ('+task+") ##################")
        print('#################################################################################')
        pred = pd.read_csv('./MuSiC/similar/Marrow_'+task+'_'+missing_celltype+'_missing_pred.csv',index_col=0,sep=',')
        label = pd.read_csv('./TabularMuris/common/Marrow_pseudobulk_'+task.split('2')[-1]+'_label.txt',sep='\t',index_col=0)
        label['Bcell_sum'] = label['late pro-B cell']+label['immature B cell']
        
        if missing_celltype == 'lpb':
            pred['Bcell_sum'] = pred['immature B cell']
            pred.drop('immature B cell',inplace=True,axis=1)
        elif missing_celltype == 'ib':
            pred['Bcell_sum'] = pred['late pro-B cell']
            pred.drop('late pro-B cell',inplace=True,axis=1)
        
        inter = pred.columns.intersection(label.columns)
        label = label[inter]
        pred = pred[inter]
        overall_ccc = CCCscore(label.values,pred.values)
        overall_l1 = L1error(label.values,pred.values)
        print('Overall ccc score is',overall_ccc)
        print('Overall L1 error is',overall_l1)
        for i in range(pred.shape[1]):
            score = CCCscore(label.iloc[:,i].values,pred.iloc[:,i].values)
            error = L1error(label.iloc[:,i].values,pred.iloc[:,i].values)
            celltype = pred.columns[i]
            print(celltype+"'s ccc score is",score,"l1 error is",error)
            record = record.append({'CellType':celltype,'CCC':score,'L1error':error,
                           'DataType':task,'MissingCell':missing_celltype,'Method':'MuSiC'},ignore_index=True)
# Out:
# #################################################################################
# ################## Evaluating MuSiC's prediction of lpb missing (counts2umi) ##################
# #################################################################################
# Overall ccc score is 0.676200893851492
# Overall L1 error is 0.08483229525801235
# hematopoietic precursor cell's ccc score is 0.31608686770456623 l1 error is 0.17502261123339177
# granulocyte's ccc score is 0.8243839652456953 l1 error is 0.06043402636845816
# monocyte's ccc score is 0.6659180746664995 l1 error is 0.07547848502889118
# macrophage's ccc score is 0.7042954270242255 l1 error is 0.06937563994515589
# basophil's ccc score is 0.9125861328349171 l1 error is 0.032561913313387404
# Bcell_sum's ccc score is 0.6907579726001739 l1 error is 0.09612109565878958
# #################################################################################
# ################## Evaluating MuSiC's prediction of lpb missing (umi2counts) ##################
# #################################################################################
# Overall ccc score is 0.22043274541488153
# Overall L1 error is 0.16563621729497716
# hematopoietic precursor cell's ccc score is 0.02471090217225072 l1 error is 0.141271508566594
# granulocyte's ccc score is 0.7362406795685773 l1 error is 0.06508516753706668
# monocyte's ccc score is 0.3452943586076141 l1 error is 0.23516773695155224
# macrophage's ccc score is 0.2346867767709785 l1 error is 0.22158027414120088
# basophil's ccc score is 0.8056917683654227 l1 error is 0.0634736361105607
# Bcell_sum's ccc score is 0.0322655214230008 l1 error is 0.26723898046288846
# #################################################################################
# ################## Evaluating MuSiC's prediction of ib missing (counts2umi) ##################
# #################################################################################
# Overall ccc score is 0.7360605100343821
# Overall L1 error is 0.07933784184098601
# hematopoietic precursor cell's ccc score is 0.5182540234101883 l1 error is 0.13842744173535787
# granulocyte's ccc score is 0.8500867701011816 l1 error is 0.05629626031977474
# monocyte's ccc score is 0.7071737919253182 l1 error is 0.06964763695001423
# macrophage's ccc score is 0.7144845651540727 l1 error is 0.07395922737377549
# basophil's ccc score is 0.8512238920358818 l1 error is 0.045995933082038004
# Bcell_sum's ccc score is 0.6904618489910481 l1 error is 0.0917005515849557
# #################################################################################
# ################## Evaluating MuSiC's prediction of ib missing (umi2counts) ##################
# #################################################################################
# Overall ccc score is 0.29047321666240494
# Overall L1 error is 0.15114151925024844
# hematopoietic precursor cell's ccc score is 0.003488218892610081 l1 error is 0.14366725475664255
# granulocyte's ccc score is 0.7345234966511807 l1 error is 0.06486349259109597
# monocyte's ccc score is 0.359407380665379 l1 error is 0.2301716781436858
# macrophage's ccc score is 0.2926061711870957 l1 error is 0.20009716908780883
# basophil's ccc score is 0.8627420066102903 l1 error is 0.05046963029350668
# Bcell_sum's ccc score is 0.1470125415608634 l1 error is 0.2175798906287506

# %%
### missing & similar
tasks = ['counts2umi','umi2counts']
missing_celltypes = ['lpb','ib']
for missing_celltype in missing_celltypes:
    for task in tasks:
        print('#################################################################################')
        print("################## Evaluating TAPE's prediction of "+missing_celltype+' missing ('+task+") ##################")
        print('#################################################################################')
        pred = pd.read_csv('./TAPE/similar/Marrow_'+task+'_'+missing_celltype+'_missing_pred.csv',index_col=0,sep=',')
        label = pd.read_csv('./TabularMuris/common/Marrow_pseudobulk_'+task.split('2')[-1]+'_label.txt',sep='\t',index_col=0)
        label['Bcell_sum'] = label['late pro-B cell']+label['immature B cell']
        
        if missing_celltype == 'lpb':
            pred['Bcell_sum'] = pred['immature B cell']
            pred.drop('immature B cell',inplace=True,axis=1)
        elif missing_celltype == 'ib':
            pred['Bcell_sum'] = pred['late pro-B cell']
            pred.drop('late pro-B cell',inplace=True,axis=1)
        
        inter = pred.columns.intersection(label.columns)
        label = label[inter]
        pred = pred[inter]
        overall_ccc = CCCscore(label.values,pred.values)
        overall_l1 = L1error(label.values,pred.values)
        print('Overall ccc score is',overall_ccc)
        print('Overall L1 error is',overall_l1)
        for i in range(pred.shape[1]):
            score = CCCscore(label.iloc[:,i].values,pred.iloc[:,i].values)
            error = L1error(label.iloc[:,i].values,pred.iloc[:,i].values)
            celltype = pred.columns[i]
            print(celltype+"'s ccc score is",score,"l1 error is",error)
            record = record.append({'CellType':celltype,'CCC':score,'L1error':error,
                           'DataType':task,'MissingCell':missing_celltype,'Method':'TAPE'},ignore_index=True)
# Out:
# #################################################################################
# ################## Evaluating TAPE's prediction of lpb missing (counts2umi) ##################
# #################################################################################
# Overall ccc score is 0.6995705794137994
# Overall L1 error is 0.07034901914040144
# basophil's ccc score is 0.5992026752938825 l1 error is 0.06409033652730463
# granulocyte's ccc score is 0.7033180527801082 l1 error is 0.06669383578739839
# hematopoietic precursor cell's ccc score is 0.7512606538474369 l1 error is 0.04797597221804934
# macrophage's ccc score is 0.7247153424893769 l1 error is 0.05921088921801339
# monocyte's ccc score is 0.6836960568334455 l1 error is 0.07876247938702421
# Bcell_sum's ccc score is 0.5757213374539496 l1 error is 0.1053606017046187
# #################################################################################
# ################## Evaluating TAPE's prediction of lpb missing (umi2counts) ##################
# #################################################################################
# Overall ccc score is 0.7367281648559416
# Overall L1 error is 0.06376175413196748
# basophil's ccc score is 0.6324211007272181 l1 error is 0.06402627743782864
# granulocyte's ccc score is 0.85780194939005 l1 error is 0.04485062562746307
# hematopoietic precursor cell's ccc score is 0.5075042277638879 l1 error is 0.09006029097498064
# macrophage's ccc score is 0.7787120805560726 l1 error is 0.060888936235256166
# monocyte's ccc score is 0.8607737086813609 l1 error is 0.040228270596731584
# Bcell_sum's ccc score is 0.620991312806901 l1 error is 0.08251612391954476
# #################################################################################
# ################## Evaluating TAPE's prediction of ib missing (counts2umi) ##################
# #################################################################################
# Overall ccc score is 0.6733069634093566
# Overall L1 error is 0.07339846388660269
# basophil's ccc score is 0.5623415687002926 l1 error is 0.06736257498115662
# granulocyte's ccc score is 0.5842744937162303 l1 error is 0.09062429744511279
# hematopoietic precursor cell's ccc score is 0.7914179221647176 l1 error is 0.04623693673144094
# macrophage's ccc score is 0.7319697911111616 l1 error is 0.05421070260874914
# monocyte's ccc score is 0.7174825896301465 l1 error is 0.07191550108316182
# Bcell_sum's ccc score is 0.5499834312016649 l1 error is 0.1100407704699948
# #################################################################################
# ################## Evaluating TAPE's prediction of ib missing (umi2counts) ##################
# #################################################################################
# Overall ccc score is 0.7476924411875371
# Overall L1 error is 0.06435301086178274
# basophil's ccc score is 0.678754089039974 l1 error is 0.060685742984708864
# granulocyte's ccc score is 0.8608769359591054 l1 error is 0.04531433930784507
# hematopoietic precursor cell's ccc score is 0.6662998163409277 l1 error is 0.06196745338627342
# macrophage's ccc score is 0.7512583312444304 l1 error is 0.06640262273536746
# monocyte's ccc score is 0.8281506444602625 l1 error is 0.06261347050309846
# Bcell_sum's ccc score is 0.639217087731413 l1 error is 0.08913443625340318

# %%
### missing & similar
tasks = ['counts2umi','umi2counts']
missing_celltypes = ['lpb','ib']
for missing_celltype in missing_celltypes:
    for task in tasks:
        print('#################################################################################')
        print("################## Evaluating RNAsieve's prediction of "+missing_celltype+' missing ('+task+") ##################")
        print('#################################################################################')
        pred = pd.read_csv('./RNAsieve/similar/Marrow_'+task+'_'+missing_celltype+'_missing_pred.csv',index_col=0,sep=',')
        label = pd.read_csv('./TabularMuris/common/Marrow_pseudobulk_'+task.split('2')[-1]+'_label.txt',sep='\t',index_col=0)
        pred.columns = [x.replace("_", " ") for x in pred.columns]
        label['Bcell_sum'] = label['late pro-B cell']+label['immature B cell']
        
        if missing_celltype == 'lpb':
            pred['Bcell_sum'] = pred['immature B cell']
            pred.drop('immature B cell',inplace=True,axis=1)
        elif missing_celltype == 'ib':
            pred['Bcell_sum'] = pred['late pro-B cell']
            pred.drop('late pro-B cell',inplace=True,axis=1)
        
        inter = pred.columns.intersection(label.columns)
        label = label[inter]
        pred = pred[inter]
        overall_ccc = CCCscore(label.values,pred.values)
        overall_l1 = L1error(label.values,pred.values)
        print('Overall ccc score is',overall_ccc)
        print('Overall L1 error is',overall_l1)
        for i in range(pred.shape[1]):
            score = CCCscore(label.iloc[:,i].values,pred.iloc[:,i].values)
            error = L1error(label.iloc[:,i].values,pred.iloc[:,i].values)
            celltype = pred.columns[i]
            print(celltype+"'s ccc score is",score,"l1 error is",error)
            record = record.append({'CellType':celltype,'CCC':score,'L1error':error,
                           'DataType':task,'MissingCell':missing_celltype,'Method':'RNAsieve'},ignore_index=True)
# Out:
# #################################################################################
# ################## Evaluating RNAsieve's prediction of lpb missing (counts2umi) ##################
# #################################################################################
# Overall ccc score is -0.05631376694637027
# Overall L1 error is 0.14516718311876678
# basophil's ccc score is -0.01283000366976816 l1 error is 0.10040375765892325
# granulocyte's ccc score is 0.04128805307510485 l1 error is 0.09365923523182282
# hematopoietic precursor cell's ccc score is -0.030780485605456414 l1 error is 0.26780037198814005
# macrophage's ccc score is -0.02542714943214439 l1 error is 0.11497920963461793
# monocyte's ccc score is 0.03793269347681882 l1 error is 0.10896227575285682
# Bcell_sum's ccc score is -0.01679632221451993 l1 error is 0.1851982484462398
# #################################################################################
# ################## Evaluating RNAsieve's prediction of lpb missing (umi2counts) ##################
# #################################################################################
# Overall ccc score is -0.10236899193159968
# Overall L1 error is 0.17229052152145385
# basophil's ccc score is -0.0675639443609261 l1 error is 0.14766048392949663
# granulocyte's ccc score is -0.027688996791698915 l1 error is 0.13842943089193283
# hematopoietic precursor cell's ccc score is 0.026781092685300177 l1 error is 0.29052209822176644
# macrophage's ccc score is 0.028618978548266588 l1 error is 0.14945976432239275
# monocyte's ccc score is -0.16515260241122284 l1 error is 0.11946194910556322
# Bcell_sum's ccc score is 0.03721732761703895 l1 error is 0.18820940265757113
# #################################################################################
# ################## Evaluating RNAsieve's prediction of ib missing (counts2umi) ##################
# #################################################################################
# Overall ccc score is -0.06061282898448686
# Overall L1 error is 0.1377185029395526
# basophil's ccc score is -0.02572711758311503 l1 error is 0.10154075882425272
# granulocyte's ccc score is -0.010666971026913354 l1 error is 0.09510668436590379
# hematopoietic precursor cell's ccc score is -0.02229966623426376 l1 error is 0.22231102829000393
# macrophage's ccc score is -0.03246909179565488 l1 error is 0.1200069134287341
# monocyte's ccc score is -0.04962249567145217 l1 error is 0.10451707385024585
# Bcell_sum's ccc score is -0.020753579989155477 l1 error is 0.18282855887817523
# #################################################################################
# ################## Evaluating RNAsieve's prediction of ib missing (umi2counts) ##################
# #################################################################################
# Overall ccc score is 0.019912118360577272
# Overall L1 error is 0.13925893835404465
# basophil's ccc score is 0.006416586884245994 l1 error is 0.1363089694378076
# granulocyte's ccc score is -0.006101043739360889 l1 error is 0.16816669383196495
# hematopoietic precursor cell's ccc score is 0.07094033657108954 l1 error is 0.16136550601980182
# macrophage's ccc score is 0.09215650260746254 l1 error is 0.11048956582875132
# monocyte's ccc score is -0.05505521268902343 l1 error is 0.12767218795015825
# Bcell_sum's ccc score is -0.023930155500609212 l1 error is 0.13155070705578395

# %%
### missing & similar
tasks = ['counts2umi','umi2counts']
missing_celltypes = ['lpb','ib']
for missing_celltype in missing_celltypes:
    for task in tasks:
        print('#################################################################################')
        print("################## Evaluating Bisque's prediction of "+missing_celltype+' missing ('+task+") ##################")
        print('#################################################################################')
        pred = pd.read_csv('./Bisque/similar/Marrow_'+task+'_'+missing_celltype+'_missing_pred.csv',index_col=0,sep=',').T
        label = pd.read_csv('./TabularMuris/common/Marrow_pseudobulk_'+task.split('2')[-1]+'_label.txt',sep='\t',index_col=0)
        pred.columns = [x.replace("_", " ") for x in pred.columns]
        label['Bcell_sum'] = label['late pro-B cell']+label['immature B cell']
        
        if missing_celltype == 'lpb':
            pred['Bcell_sum'] = pred['immature B cell']
            pred.drop('immature B cell',inplace=True,axis=1)
        elif missing_celltype == 'ib':
            pred['Bcell_sum'] = pred['late pro-B cell']
            pred.drop('late pro-B cell',inplace=True,axis=1)
        
        inter = pred.columns.intersection(label.columns)
        label = label[inter]
        pred = pred[inter]
        overall_ccc = CCCscore(label.values,pred.values)
        overall_l1 = L1error(label.values,pred.values)
        print('Overall ccc score is',overall_ccc)
        print('Overall L1 error is',overall_l1)
        for i in range(pred.shape[1]):
            score = CCCscore(label.iloc[:,i].values,pred.iloc[:,i].values)
            error = L1error(label.iloc[:,i].values,pred.iloc[:,i].values)
            celltype = pred.columns[i]
            print(celltype+"'s ccc score is",score,"l1 error is",error)
            record = record.append({'CellType':celltype,'CCC':score,'L1error':error,
                           'DataType':task,'MissingCell':missing_celltype,'Method':'Bisque'},ignore_index=True)
# Out:
# #################################################################################
# ################## Evaluating Bisque's prediction of lpb missing (counts2umi) ##################
# #################################################################################
# Overall ccc score is 0.4563394066070459
# Overall L1 error is 0.14210878351054101
# basophil's ccc score is 0.6858881631155442 l1 error is 0.10075361926005721
# granulocyte's ccc score is 0.7094144391420409 l1 error is 0.0991015608283241
# hematopoietic precursor cell's ccc score is 0.2997820644343948 l1 error is 0.1353446281592577
# macrophage's ccc score is 0.3252093569342155 l1 error is 0.17099736574993613
# monocyte's ccc score is 0.6332746499078205 l1 error is 0.11355189127879477
# Bcell_sum's ccc score is 0.20310185807615505 l1 error is 0.23290363578687606
# #################################################################################
# ################## Evaluating Bisque's prediction of lpb missing (umi2counts) ##################
# #################################################################################
# Overall ccc score is 0.5659363648871325
# Overall L1 error is 0.11740994257215934
# basophil's ccc score is 0.7058731058603398 l1 error is 0.09689305050784863
# granulocyte's ccc score is 0.6521437685336886 l1 error is 0.11230716869788417
# hematopoietic precursor cell's ccc score is 0.4593228187125628 l1 error is 0.11992610661118049
# macrophage's ccc score is 0.5791395398587954 l1 error is 0.09732222522037967
# monocyte's ccc score is 0.6222461220739837 l1 error is 0.1166155680541964
# Bcell_sum's ccc score is 0.30068835775004327 l1 error is 0.1613955363414666
# #################################################################################
# ################## Evaluating Bisque's prediction of ib missing (counts2umi) ##################
# #################################################################################
# Overall ccc score is 0.48011811836965657
# Overall L1 error is 0.1393493610387914
# basophil's ccc score is 0.6846166666390567 l1 error is 0.10072719180391378
# granulocyte's ccc score is 0.7110370503857646 l1 error is 0.0970672921019355
# hematopoietic precursor cell's ccc score is 0.21264912831902044 l1 error is 0.14087408501381682
# macrophage's ccc score is 0.364975207670616 l1 error is 0.15543359028301507
# monocyte's ccc score is 0.6372800187496186 l1 error is 0.11167124172617679
# Bcell_sum's ccc score is 0.25573797703831375 l1 error is 0.23032276530389023
# #################################################################################
# ################## Evaluating Bisque's prediction of ib missing (umi2counts) ##################
# #################################################################################
# Overall ccc score is 0.6250388024779446
# Overall L1 error is 0.11005512665829734
# basophil's ccc score is 0.6960386200464758 l1 error is 0.10033914530199942
# granulocyte's ccc score is 0.6535959706947864 l1 error is 0.11134486804390964
# hematopoietic precursor cell's ccc score is 0.6596660558030891 l1 error is 0.08205927985117971
# macrophage's ccc score is 0.6214278045952372 l1 error is 0.09215110679831641
# monocyte's ccc score is 0.6365506294772374 l1 error is 0.116926088969592
# Bcell_sum's ccc score is 0.46855819485768385 l1 error is 0.1575102709847869

# %%
record.to_csv('./pseudobulk_similar_result.csv')
